# %% [markdown]
# ## Query and Generate response
# - at top-k = 10 model seems to generate the wrong query string and failed to retrieve

# %%
import os
import pandas as pd
import re
import time
from io import StringIO

# Import the pipeline that calls the LLM
from utils.pipeline import run_pipeline

# Configurable parameter: top_k (must be less than 15)
TOP_K = 5  # Adjust as needed

# Paths
TESTSET_CSV_PATH = "/home/jaf/battery-lifespan-kg/eval/evaluator_question.csv"  # Update if needed
BATTERY_FILES_DIR = "/home/jaf/battery-lifespan-kg/resources/testset"
OUTPUT_DIR = "/home/jaf/battery-lifespan-kg/eval"

def save_llm_responses():
    # Read the testset CSV
    df = pd.read_csv(TESTSET_CSV_PATH)
    
    # Identify and sort sample question columns (e.g., SAMPLE_QUESTION_1, SAMPLE_QUESTION_2, ...)
    sample_question_cols = sorted(
        [col for col in df.columns if col.startswith("SAMPLE_QUESTION")],
        key=lambda x: int(x.split('_')[-1])
    )
    
    output_rows = []
    total_cases = len(df)
    
    try:
        # Iterate over each test case
        for idx, row in df.iterrows():
            test_battery_id = row["TEST_BATTERY_ID"]
            test_battery_query_feature = row["TEST_BATTERY_QUERY_FEATURE"]
            print(f"\nProcessing test case {idx+1}/{total_cases}: Battery {test_battery_id} with feature '{test_battery_query_feature}'")
            battery_file_path = os.path.join(BATTERY_FILES_DIR, f"{test_battery_id}.txt")
            
            # Read the battery file content
            try:
                with open(battery_file_path, "r") as f:
                    file_content = f.read()
            except Exception as e:
                print(f"Error reading file for battery {test_battery_id}: {e}")
                continue
            
            # Prepare the row data dictionary with base columns
            row_data = {
                "TEST_BATTERY_ID": test_battery_id,
                "TEST_BATTERY_QUERY_FEATURE": test_battery_query_feature
            }
            
            # For each sample question, obtain the raw LLM response
            for i, question_col in enumerate(sample_question_cols, start=1):
                base_question = str(row[question_col]).strip()
                print(f"  Processing question {i}: {base_question}")
                
                # Append instruction to force the list format with top-K results
                modified_question = (
                    f"{base_question} return the top-{TOP_K} results from the most similar first. "
                    "Please respond with a comma-separated list of battery IDs only."
                )
                
                # Create a new file-like object for each call (to avoid pointer issues)
                uploaded_file = StringIO(file_content)
                
                try:
                    # Run the pipeline with the modified question and the file content
                    response = run_pipeline(modified_question, uploaded_file)
                    if isinstance(response, str):
                        raw_response = response
                    else:
                        raw_response = response.get("result", "")
                    print(f"    Received response: {raw_response[:50]}...")  # Print first 50 characters
                except Exception as e:
                    raw_response = f"API error: {str(e)}"
                    print(f"    Error processing battery {test_battery_id} question '{base_question}': {str(e)}")
                
                # Save the original question and its raw response in the row data
                row_data[f"q{i}"] = base_question
                row_data[f"q{i}_raw_response"] = raw_response
                
                # Optional delay between questions to avoid rate limiting
                time.sleep(1)
            
            output_rows.append(row_data)
    except Exception as global_error:
        print(f"\nA global error occurred: {str(global_error)}")
    finally:
        # Create a DataFrame from the collected rows even if an error occurred
        output_df = pd.DataFrame(output_rows)
        
        # Construct the output CSV path using the input CSV name
        input_csv_name = os.path.basename(TESTSET_CSV_PATH)
        output_csv_path = os.path.join(OUTPUT_DIR, f"llm_response_for_{input_csv_name}.csv")
        
        # Save the DataFrame to CSV
        output_df.to_csv(output_csv_path, index=False)
        print(f"\nLLM responses saved to {output_csv_path}")

save_llm_responses()
# Out:
# Processing test case 1/100: Battery b3c7 with feature 'slope_last_10_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_10_cycles feature?'
#     Received response: b1c1, b1c3, b1c4, b1c2, b1c0...
#   Processing question 2: 'Are there any batteries that match a slope_last_10_cycles feature?'
#     Received response: b1c0, b1c2, b1c4, b1c3, b1c1...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_10_cycles feature?'
#     Received response: b1c1, b1c3, b1c4, b1c2, b1c0...
#
# Processing test case 2/100: Battery b3c7 with feature 'mean_grad_last_10_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_10_cycles as this unknown one?'
#     Received response: b1c1, b1c3, b1c4
#
# (Note: Since there are only thr...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_10_cycles of this unidentified battery?'
#     Received response: b1c2, b1c0, b1c4, b1c3, b1c1...
#   Processing question 3: 'Can you locate batteries with a similar mean_grad_last_10_cycles to this mystery battery?'
#     Received response: b1c1, b1c3, b1c4
#
# (Note: Since there are only thr...
#
# Processing test case 3/100: Battery b3c7 with feature 'slope_last_50_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_50_cycles feature?'
#     Received response: b1c0, b1c1, b1c4, b1c2, b1c3...
#   Processing question 2: 'Are there any batteries that match a slope_last_50_cycles feature?'
#     Received response: b1c0, b1c1, b1c4, b1c2, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_50_cycles characteristic?'
#     Received response: b1c3, b1c2, b1c4, b1c1, b1c0...
#
# Processing test case 4/100: Battery b3c7 with feature 'mean_grad_last_50_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar mean_grad_last_50_cycles feature?'
#     Received response: b1c2, b1c3, b1c4, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that share the same mean_grad_last_50_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 3: 'Can you locate batteries with a comparable mean_grad_last_50_cycles attribute?'
#     Received response: b1c2, b1c3, b1c4, b1c1, b1c0...
#
# Processing test case 5/100: Battery b3c7 with feature 'slope_last_100_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_100_cycles feature?'
#     Received response: b1c2, b1c3, b1c4, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that match the slope_last_100_cycles feature of this unknown battery?'
#     Received response: b1c0, b1c1, b1c4, b1c3, b1c2...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_100_cycles characteristic?'
#     Received response: b1c2, b1c3, b1c4, b1c1, b1c0...
#
# Processing test case 6/100: Battery b3c7 with feature 'mean_grad_last_100_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar mean_grad_last_100_cycles feature?'
#     Received response: b1c2, b1c3, b1c1, b1c4, b1c0...
#   Processing question 2: 'Are there any batteries that share the same mean_grad_last_100_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 3: 'Can you locate batteries with a comparable mean_grad_last_100_cycles attribute?'
#     Received response: b1c2, b1c3, b1c1, b1c4, b1c0...
#
# Processing test case 7/100: Battery b3c7 with feature 'slope_last_200_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_200_cycles feature as this one?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that match this one in terms of the slope_last_200_cycles feature?'
#     Received response: b1c4, b1c3, b1c2, b1c1, b1c0...
#   Processing question 3: 'Can you locate batteries with a slope_last_200_cycles feature that is comparable to this one?'
#     Received response: b1c4, b1c3, b1c2, b1c1, b1c0...
#
# Processing test case 8/100: Battery b3c7 with feature 'mean_grad_last_200_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar mean_grad_last_200_cycles feature?'
#     Received response: b1c4, b1c2, b1c3, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that share the same mean_grad_last_200_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 3: 'Can you locate batteries with a comparable mean_grad_last_200_cycles attribute?'
#     Received response: b1c4, b1c3, b1c2, b1c1, b1c0...
#
# Processing test case 9/100: Battery b3c7 with feature 'slope_last_300_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_300_cycles feature?'
#     Received response: b1c0, b1c3, b1c1, b1c2, b1c4...
#   Processing question 2: 'Are there any batteries that match the slope_last_300_cycles feature of this unknown battery?'
#     Received response: b1c4, b1c2, b1c1, b1c3, b1c0...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_300_cycles characteristic?'
# Error invoking chain: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '|': expected an expression, 'FOREACH', 'ORDER BY', 'CALL', 'CREATE', 'LOAD CSV', 'DELETE', 'DETACH', 'FINISH', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REMOVE', 'RETURN', 'SET', 'SKIP', 'UNION', 'UNWIND', 'USE', 'WITH' or <EOF> (line 1, column 131 (offset: 130))
# "MATCH (b:Battery) RETURN b.battery_id, abs(b.slope_last_300_cycles - (-0.00035009324550628663)) as diff ORDER BY diff ASC LIMIT 5 |"
#                                                                                                                                    ^}. Returning empty response for scoring.
#     Received response: ...
#
# Processing test case 10/100: Battery b3c7 with feature 'mean_grad_last_300_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_300_cycles as this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c0, b1c4...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_300_cycles of this particular battery?'
#     Received response: b1c4, b1c2, b1c1, b1c3, b1c0...
#   Processing question 3: 'Could you locate batteries with a similar mean_grad_last_300_cycles to this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c0...
#
# Processing test case 11/100: Battery b3c7 with feature 'slope_last_400_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_400_cycles feature?'
#     Received response: b1c4, b1c2, b1c3, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that match a slope_last_400_cycles feature?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_400_cycles feature?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#
# Processing test case 12/100: Battery b3c7 with feature 'mean_grad_last_400_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_400_cycles as this unknown one?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_400_cycles of this unidentified battery?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#   Processing question 3: 'Can you locate batteries with a similar mean_grad_last_400_cycles to this mystery battery?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 13/100: Battery b3c7 with feature 'slope_last_500_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_500_cycles feature?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_500_cycles feature of this unknown battery?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_500_cycles characteristic?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#
# Processing test case 14/100: Battery b3c7 with feature 'mean_grad_last_500_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_500_cycles as this unknown one?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#   Processing question 2: 'Could you identify batteries that have a mean_grad_last_500_cycles similar to this unknown battery?'
#     Received response: To find the batteries with a mean_grad_last_500_cy...
#   Processing question 3: 'Is it possible to locate batteries with a mean_grad_last_500_cycles that matches this unknown battery?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#
# Processing test case 15/100: Battery b3c7 with feature 'slope_last_600_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_600_cycles feature?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_600_cycles feature of this unknown battery?'
#     Received response: b1c1, b1c4, b1c2, b1c0, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_600_cycles characteristic?'
#     Received response: b1c1, b1c4, b1c2, b1c0, b1c3...
#
# Processing test case 16/100: Battery b3c7 with feature 'mean_grad_last_600_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_600_cycles as this unknown one?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_600_cycles of this particular battery?'
#     Received response: b1c1, b1c4, b1c0, b1c2, b1c3...
#   Processing question 3: 'Can you locate batteries with a similar mean_grad_last_600_cycles to this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 17/100: Battery b3c7 with feature 'slope_last_700_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_700_cycles feature?'
#     Received response: b1c3, b1c4, b1c2, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that match a slope_last_700_cycles feature?'
#     Received response: b1c3, b1c4, b1c2, b1c1, b1c0...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_700_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 18/100: Battery b3c7 with feature 'mean_grad_last_700_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_700_cycles as this one?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c0...
#   Processing question 2: 'Are there any batteries with a similar mean_grad_last_700_cycles to this one?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c0...
#   Processing question 3: 'Could you locate batteries that have a mean_grad_last_700_cycles similar to this one?'
#     Received response: To find the batteries with a mean_grad_last_700_cy...
#
# Processing test case 19/100: Battery b3c7 with feature 'slope_last_800_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_800_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_800_cycles feature of this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_800_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 20/100: Battery b3c7 with feature 'mean_grad_last_800_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_800_cycles as this unknown one?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#   Processing question 2: 'Could you identify batteries that have a mean_grad_last_800_cycles similar to this unknown battery?'
#     Received response: To find the batteries with a mean_grad_last_800_cy...
#   Processing question 3: 'Is it possible to locate batteries with a mean_grad_last_800_cycles that matches this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 21/100: Battery b3c7 with feature 'slope_last_900_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_900_cycles feature?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_900_cycles feature of this unknown battery?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_900_cycles characteristic?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#
# Processing test case 22/100: Battery b3c7 with feature 'mean_grad_last_900_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_900_cycles as this unknown one?'
#     Received response: b1c1, b1c2, b1c0, b1c4, b1c3...
#   Processing question 2: 'Could you identify batteries that have a mean_grad_last_900_cycles similar to this unknown battery?'
#     Received response: To find the batteries with a mean_grad_last_900_cy...
#   Processing question 3: 'Is it possible to locate batteries with a mean_grad_last_900_cycles that matches this unknown battery?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#
# Processing test case 23/100: Battery b3c7 with feature 'slope_last_1000_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_1000_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_1000_cycles of this particular one?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_1000_cycles?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 24/100: Battery b3c7 with feature 'mean_grad_last_1000_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_1000_cycles as this unknown one?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#   Processing question 2: 'Could you identify batteries that match the mean_grad_last_1000_cycles of this particular battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Is it possible to locate batteries with a similar mean_grad_last_1000_cycles to this unknown battery?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#
# Processing test case 25/100: Battery b3c7 with feature 'cycle'
#   Processing question 1: 'Can you identify batteries that have a similar cycle to this one?'
#     Received response: b1c3, b1c2, b1c1, b1c4, b1c0...
#   Processing question 2: 'Are there any batteries with a cycle similar to this one?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 3: 'Could you locate batteries that have a comparable cycle to this one?'
#     Received response: b1c3, b1c2, b1c1, b1c4, b1c0...
#
# Processing test case 26/100: Battery b3c10 with feature 'slope_last_10_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_10_cycles feature?'
#     Received response: b1c0, b1c4, b1c3, b1c41, b1c2...
#   Processing question 2: 'Are there any batteries that share the same slope_last_10_cycles characteristic?'
#     Received response: b1c0, b1c2...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_10_cycles attribute?'
#     Received response: b1c0, b1c2, b1c3, b1c4, b1c41...
#
# Processing test case 27/100: Battery b3c10 with feature 'mean_grad_last_10_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar mean_grad_last_10_cycles feature?'
#     Received response: b1c0, b1c2, b1c28, b1c4, b1c41...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_10_cycles feature of this unknown battery?'
#     Received response: b1c0, b1c2, b1c28, b1c4, b1c41...
#   Processing question 3: 'Can you locate batteries with a comparable mean_grad_last_10_cycles feature?'
#     Received response: b1c0, b1c2, b1c41, b1c4, b1c28...
#
# Processing test case 28/100: Battery b3c10 with feature 'slope_last_50_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_50_cycles feature?'
#     Received response: b1c24, b1c14, b1c29, b1c28, b1c41...
#   Processing question 2: 'Are there any batteries that share the same slope_last_50_cycles characteristic?'
#     Received response: b1c41, b1c28, b1c29...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_50_cycles attribute?'
#     Received response: b1c28, b1c29, b1c41, b1c24, b1c14...
#
# Processing test case 29/100: Battery b3c10 with feature 'mean_grad_last_50_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_50_cycles as this unknown battery?'
#     Received response: b1c41, b1c28, b1c29
#
# (Note: Since there are only ...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_50_cycles of this particular battery?'
#     Received response: b1c24, b1c14, b1c29, b1c28, b1c41...
#   Processing question 3: 'Could you locate batteries with a similar mean_grad_last_50_cycles to this unknown battery?'
#     Received response: b1c41, b1c28, b1c29...
#
# Processing test case 30/100: Battery b3c10 with feature 'slope_last_100_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_100_cycles feature as the unknown one?'
#     Received response: b1c20, b1c29, b1c28, b1c24, b1c41...
#   Processing question 2: 'Are there any batteries that match the slope_last_100_cycles feature of the unknown battery?'
#     Received response: b1c20, b1c29, b1c28, b1c41, b1c24...
#   Processing question 3: 'Can you locate batteries with a slope_last_100_cycles feature that is comparable to the unknown battery?'
#     Received response: b1c20, b1c29, b1c28, b1c24, b1c41...
#
# Processing test case 31/100: Battery b3c10 with feature 'mean_grad_last_100_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_100_cycles as this one?'
#     Received response: b1c20, b1c29, b1c28, b1c24, b1c41...
#   Processing question 2: 'Are there any batteries with a similar mean_grad_last_100_cycles to this one?'
#     Received response: b1c41, b1c24, b1c28, b1c29, b1c20...
#   Processing question 3: 'Could you locate batteries that have a mean_grad_last_100_cycles similar to this one?'
#     Received response: b1c41, b1c24, b1c28, b1c29, b1c20...
#
# Processing test case 32/100: Battery b3c10 with feature 'slope_last_200_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_200_cycles feature?'
#     Received response: b1c41, b1c40, b1c9, b1c24, b1c23...
#   Processing question 2: 'Are there any batteries that match a slope_last_200_cycles feature?'
#     Received response: b1c23, b1c24, b1c9, b1c41, b1c40...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_200_cycles characteristic?'
#     Received response: b1c41, b1c40, b1c9, b1c24, b1c23...
#
# Processing test case 33/100: Battery b3c10 with feature 'mean_grad_last_200_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar mean_grad_last_200_cycles feature?'
#     Received response: b1c41, b1c40, b1c9, b1c24, b1c23...
#   Processing question 2: 'Are there any batteries that share the same mean_grad_last_200_cycles characteristic?'
#     Received response: b1c41, b1c40, b1c9, b1c24, b1c23...
#   Processing question 3: 'Can you locate batteries with a comparable mean_grad_last_200_cycles attribute?'
#     Received response: b1c41, b1c40, b1c9, b1c24, b1c23...
#
# Processing test case 34/100: Battery b3c10 with feature 'slope_last_300_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_300_cycles feature?'
#     Received response: b1c20, b1c18, b1c24, b1c41, b1c5...
#   Processing question 2: 'Are there any batteries that match a slope_last_300_cycles feature?'
#     Received response: b1c18, b1c24, b1c41, b1c5, b1c20...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_300_cycles feature?'
#     Received response: b1c20, b1c18, b1c24, b1c41, b1c5...
#
# Processing test case 35/100: Battery b3c10 with feature 'mean_grad_last_300_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_300_cycles as this unknown battery?'
#     Received response: b1c20, b1c18, b1c24, b1c41, b1c5...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_300_cycles of this particular battery?'
#     Received response: b1c5, b1c41, b1c24, b1c18, b1c20...
#   Processing question 3: 'Could you locate batteries with a similar mean_grad_last_300_cycles to this unknown battery?'
#     Received response: b1c20, b1c18, b1c24, b1c41, b1c5...
#
# Processing test case 36/100: Battery b3c10 with feature 'slope_last_400_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_400_cycles feature?'
#     Received response: b1c24, b1c11, b1c5, b1c3, b1c18...
#   Processing question 2: 'Are there any batteries that match the slope_last_400_cycles feature of this unknown battery?'
#     Received response: b1c24, b1c11, b1c5, b1c3, b1c18...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_400_cycles characteristic?'
#     Received response: b1c24, b1c11, b1c5, b1c3, b1c18...
#
# Processing test case 37/100: Battery b3c10 with feature 'mean_grad_last_400_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_400_cycles as this one?'
#     Received response: b1c18, b1c3, b1c5, b1c11, b1c24...
#   Processing question 2: 'Are there any batteries that match this one in terms of mean_grad_last_400_cycles?'
#     Received response: b1c24, b1c11, b1c5, b1c3, b1c18...
#   Processing question 3: 'Could you locate batteries with a similar mean_grad_last_400_cycles to this particular one?'
#     Received response: b1c18, b1c3, b1c5, b1c11, b1c24...
#
# Processing test case 38/100: Battery b3c10 with feature 'slope_last_500_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_500_cycles feature?'
#     Received response: b1c3, b1c11, b1c18, b1c5, b1c24...
#   Processing question 2: 'Are there any batteries that match the slope_last_500_cycles feature of this unknown battery?'
#     Received response: b1c3, b1c11, b1c18, b1c5, b1c24...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_500_cycles characteristic?'
#     Received response: b1c3, b1c11, b1c18, b1c5, b1c24...
#
# Processing test case 39/100: Battery b3c10 with feature 'mean_grad_last_500_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_500_cycles as this one?'
#     Received response: b1c3, b1c11, b1c18, b1c5, b1c24...
#   Processing question 2: 'Are there any batteries with a similar mean_grad_last_500_cycles to this one?'
#     Received response: b1c3, b1c11, b1c18, b1c5, b1c24...
#   Processing question 3: 'Could you locate batteries that have a mean_grad_last_500_cycles similar to this one?'
#     Received response: b1c3, b1c11, b1c18, b1c5, b1c24...
#
# Processing test case 40/100: Battery b3c10 with feature 'slope_last_600_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_600_cycles feature?'
#     Received response: b1c29, b1c43, b1c9, b1c28, b1c37...
#   Processing question 2: 'Are there any batteries that match the slope_last_600_cycles feature of this unknown battery?'
#     Received response: b1c5, b1c24, b1c4, b1c11, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_600_cycles characteristic?'
#     Received response: b1c3, b1c11, b1c4, b1c24, b1c5...
#
# Processing test case 41/100: Battery b3c10 with feature 'mean_grad_last_600_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_600_cycles as this one?'
#     Received response: b1c3, b1c11, b1c4, b1c24, b1c5...
#   Processing question 2: 'Are there any batteries that match this one in terms of mean_grad_last_600_cycles?'
#     Received response: b1c3, b1c11, b1c4, b1c24, b1c5...
#   Processing question 3: 'Can you locate batteries with a similar mean_grad_last_600_cycles to this particular one?'
#     Received response: b1c3, b1c11, b1c4, b1c24, b1c5...
#
# Processing test case 42/100: Battery b3c10 with feature 'slope_last_700_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_700_cycles feature?'
# Error invoking chain: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '|': expected an expression, 'FOREACH', 'ORDER BY', 'CALL', 'CREATE', 'LOAD CSV', 'DELETE', 'DETACH', 'FINISH', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REMOVE', 'RETURN', 'SET', 'SKIP', 'UNION', 'UNWIND', 'USE', 'WITH' or <EOF> (line 1, column 130 (offset: 129))
# "MATCH (b:Battery) RETURN b.battery_id, abs(b.slope_last_700_cycles - (-0.0002472104345049177)) as diff ORDER BY diff ASC LIMIT 5 |"
#                                                                                                                                   ^}. Returning empty response for scoring.
#     Received response: ...
#   Processing question 2: 'Are there any batteries that match the slope_last_700_cycles feature of this unknown battery?'
#     Received response: b1c3, b1c11, b1c4, b1c15, b1c24...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_700_cycles characteristic?'
#     Received response: b1c3, b1c11, b1c4, b1c15, b1c24...
#
# Processing test case 43/100: Battery b3c10 with feature 'mean_grad_last_700_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_700_cycles as this unknown battery?'
#     Received response: b1c3, b1c11, b1c4, b1c15, b1c24...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_700_cycles of this particular battery?'
#     Received response: b1c3, b1c11, b1c4, b1c15, b1c24...
#   Processing question 3: 'Could you locate batteries with a similar mean_grad_last_700_cycles to this unknown battery?'
#     Received response: b1c3, b1c11, b1c4, b1c15, b1c24...
#
# Processing test case 44/100: Battery b3c10 with feature 'slope_last_800_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_800_cycles feature?'
#     Received response: b1c17, b1c24, b1c5, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_800_cycles feature of this unknown battery?'
#     Received response: b1c17, b1c24, b1c5, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_800_cycles characteristic?'
#     Received response: b1c17, b1c24, b1c5, b1c4, b1c3...
#
# Processing test case 45/100: Battery b3c10 with feature 'mean_grad_last_800_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_800_cycles as this unknown one?'
#     Received response: b1c3, b1c4, b1c5, b1c24, b1c17...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_800_cycles of this unidentified battery?'
#     Received response: b1c17, b1c24, b1c5, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a similar mean_grad_last_800_cycles to this mystery battery?'
#     Received response: b1c3, b1c4, b1c5, b1c24, b1c17...
#
# Processing test case 46/100: Battery b3c10 with feature 'slope_last_900_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_900_cycles feature?'
# Error invoking chain: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '|': expected an expression, 'FOREACH', 'ORDER BY', 'CALL', 'CREATE', 'LOAD CSV', 'DELETE', 'DETACH', 'FINISH', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REMOVE', 'RETURN', 'SET', 'SKIP', 'UNION', 'UNWIND', 'USE', 'WITH' or <EOF> (line 1, column 131 (offset: 130))
# "MATCH (b:Battery) RETURN b.battery_id, abs(b.slope_last_900_cycles - (-0.00020084804958767362)) as diff ORDER BY diff ASC LIMIT 5 |"
#                                                                                                                                    ^}. Returning empty response for scoring.
#     Received response: ...
#   Processing question 2: 'Are there any batteries that match the slope_last_900_cycles feature of this unknown battery?'
#     Received response: b1c3, b1c4, b1c5, b1c24, b1c41...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_900_cycles characteristic?'
#     Received response: b1c3, b1c4, b1c24, b1c5, b1c41...
#
# Processing test case 47/100: Battery b3c10 with feature 'mean_grad_last_900_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_900_cycles as this unknown battery?'
#     Received response: b1c3, b1c4, b1c5, b1c24, b1c41...
#   Processing question 2: 'Are there any batteries that share the same mean_grad_last_900_cycles as this particular battery?'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 71, offset: 172} for query: 'MATCH (b1:Battery {mean_grad_last_900_cycles: -0.00020082573095957438}) \nWITH b1 \nMATCH (b2:Battery) \nWHERE b2.mean_grad_last_900_cycles = b1.mean_grad_last_900_cycles AND id(b2) <> id(b1) \nRETURN b2.battery_id \nORDER BY abs(b2.mean_grad_last_900_cycles - b1.mean_grad_last_900_cycles) \nLIMIT 5'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 81, offset: 182} for query: 'MATCH (b1:Battery {mean_grad_last_900_cycles: -0.00020082573095957438}) \nWITH b1 \nMATCH (b2:Battery) \nWHERE b2.mean_grad_last_900_cycles = b1.mean_grad_last_900_cycles AND id(b2) <> id(b1) \nRETURN b2.battery_id \nORDER BY abs(b2.mean_grad_last_900_cycles - b1.mean_grad_last_900_cycles) \nLIMIT 5'
#     Received response: I don't know the answer....
#   Processing question 3: 'Could you locate batteries that match this unknown battery in terms of mean_grad_last_900_cycles?'
#     Received response: b1c4, b1c3, b1c5, b1c24, b1c41...
#
# Processing test case 48/100: Battery b3c10 with feature 'slope_last_1000_cycles'
#   Processing question 1: 'Are there any batteries that have a similar slope_last_1000_cycles feature as this one?'
#     Received response: b1c4, b1c3, b1c24, b1c5, b1c23...
#   Processing question 2: 'Could you identify batteries that match this one in terms of slope_last_1000_cycles?'
#     Received response: b1c4, b1c3, b1c24, b1c5, b1c23...
#   Processing question 3: 'Is it possible to locate batteries with a comparable slope_last_1000_cycles to this one?'
#     Received response: b1c4, b1c3, b1c24, b1c5, b1c23...
#
# Processing test case 49/100: Battery b3c10 with feature 'mean_grad_last_1000_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_1000_cycles as this unknown one?'
#     Received response: b1c4, b1c3, b1c24, b1c5, b1c23...
#   Processing question 2: 'Could you identify batteries that match the mean_grad_last_1000_cycles of this particular battery?'
#     Received response: b1c4, b1c3, b1c24, b1c5, b1c23...
#   Processing question 3: 'Is it possible to locate batteries with a similar mean_grad_last_1000_cycles to this unknown battery?'
#     Received response: b1c4, b1c3, b1c24, b1c5, b1c23...
#
# Processing test case 50/100: Battery b3c10 with feature 'cycle'
#   Processing question 1: 'Can you identify batteries that have a similar cycle to an unknown one?'
#     Received response: b1c41, b1c24, b1c24, b1c41, b1c9...
#   Processing question 2: 'Are there any batteries that share a similar cycle with an unknown one?'
#     Received response: b1c41, b1c24, b1c24, b1c41, b1c9...
#   Processing question 3: 'Can you locate batteries with a cycle similar to an unknown one?'
#     Received response: b1c41, b1c24, b1c41, b1c24, b1c9...
#
# Processing test case 51/100: Battery b3c16 with feature 'slope_last_10_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_10_cycles feature as the unknown one?'
#     Received response: b1c4, b1c3, b1c2, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that match the unknown one in terms of the slope_last_10_cycles feature?'
#     Received response: b1c2, b1c0, b1c1, b1c3, b1c4...
#   Processing question 3: 'Can you locate batteries that share the same slope_last_10_cycles characteristic as the unknown battery?'
#     Received response: b1c1, b1c3, b1c4...
#
# Processing test case 52/100: Battery b3c16 with feature 'mean_grad_last_10_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar mean_grad_last_10_cycles feature as the unknown one?'
#     Received response: b1c1, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that match the unknown one in terms of mean_grad_last_10_cycles?'
#     Received response: b1c4, b1c3, b1c2, b1c1, b1c0...
#   Processing question 3: 'Can you locate batteries with a mean_grad_last_10_cycles feature that is comparable to the unknown battery?'
#     Received response: b1c4, b1c3, b1c1, b1c2, b1c0...
#
# Processing test case 53/100: Battery b3c16 with feature 'slope_last_50_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_50_cycles feature?'
#     Received response: b1c3, b1c2, b1c4, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that match a slope_last_50_cycles feature?'
#     Received response: b1c0, b1c1, b1c4, b1c2, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_50_cycles feature?'
#     Received response: b1c3, b1c2, b1c4, b1c1, b1c0...
#
# Processing test case 54/100: Battery b3c16 with feature 'mean_grad_last_50_cycles'
#   Processing question 1: 'Are there any batteries that have a similar mean_grad_last_50_cycles as this unknown one?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c0...
#   Processing question 2: 'Could you identify batteries that match the mean_grad_last_50_cycles of this particular battery?'
#     Received response: b1c3, b1c2, b1c4, b1c1, b1c0...
#   Processing question 3: 'Is it possible to locate batteries with a mean_grad_last_50_cycles similar to this unknown battery?'
#     Received response: b1c3, b1c2, b1c4, b1c1, b1c0...
#
# Processing test case 55/100: Battery b3c16 with feature 'slope_last_100_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_100_cycles feature?'
#     Received response: b1c3, b1c2, b1c4, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that match a slope_last_100_cycles feature?'
#     Received response: b1c3, b1c2, b1c4, b1c1, b1c0...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_100_cycles feature?'
#     Received response: b1c3, b1c2, b1c4, b1c1, b1c0...
#
# Processing test case 56/100: Battery b3c16 with feature 'mean_grad_last_100_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_100_cycles as this unknown one?'
#     Received response: b1c3, b1c2, b1c4, b1c0, b1c1...
#   Processing question 2: 'Could you identify batteries that have a mean_grad_last_100_cycles similar to this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c0...
#   Processing question 3: 'Is it possible to locate batteries with a mean_grad_last_100_cycles that matches this unknown battery?'
#     Received response: b1c3, b1c2, b1c4, b1c0, b1c1...
#
# Processing test case 57/100: Battery b3c16 with feature 'slope_last_200_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_200_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that match a slope_last_200_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_200_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 58/100: Battery b3c16 with feature 'mean_grad_last_200_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar mean_grad_last_200_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that share the same mean_grad_last_200_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 3: 'Can you locate batteries with a comparable mean_grad_last_200_cycles attribute?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 59/100: Battery b3c16 with feature 'slope_last_300_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_300_cycles feature?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c20...
#   Processing question 2: 'Are there any batteries that match a slope_last_300_cycles feature?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c20...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_300_cycles characteristic?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c20...
#
# Processing test case 60/100: Battery b3c16 with feature 'mean_grad_last_300_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_300_cycles as this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_300_cycles of this particular battery?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c20...
#   Processing question 3: 'Could you locate batteries with a similar mean_grad_last_300_cycles to this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 61/100: Battery b3c16 with feature 'slope_last_400_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_400_cycles feature?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#   Processing question 2: 'Are there any batteries that match the slope_last_400_cycles feature of this unknown battery?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_400_cycles characteristic?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#
# Processing test case 62/100: Battery b3c16 with feature 'mean_grad_last_400_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_400_cycles as this one?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that match this one in terms of mean_grad_last_400_cycles?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#   Processing question 3: 'Could you locate batteries with a similar mean_grad_last_400_cycles to this particular one?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 63/100: Battery b3c16 with feature 'slope_last_500_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_500_cycles feature?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_500_cycles feature of this unknown battery?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_500_cycles characteristic?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#
# Processing test case 64/100: Battery b3c16 with feature 'mean_grad_last_500_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_500_cycles as this unknown one?'
#     Received response: b1c1, b1c2, b1c3, b1c0, b1c4...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_500_cycles of this particular one?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#   Processing question 3: 'Can you locate batteries with a similar mean_grad_last_500_cycles to this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 65/100: Battery b3c16 with feature 'slope_last_600_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_600_cycles feature?'
#     Received response: b1c3, b1c0, b1c2, b1c1, b1c4...
#   Processing question 2: 'Are there any batteries that match the slope_last_600_cycles feature of this unknown battery?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_600_cycles characteristic?'
#     Received response: b1c1, b1c2, b1c0, b1c4, b1c3...
#
# Processing test case 66/100: Battery b3c16 with feature 'mean_grad_last_600_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_600_cycles as this unknown one?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#   Processing question 2: 'Could you identify batteries that have a mean_grad_last_600_cycles similar to this unknown battery?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#   Processing question 3: 'Is it possible to locate batteries with a mean_grad_last_600_cycles that matches this unknown battery?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#
# Processing test case 67/100: Battery b3c16 with feature 'slope_last_700_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_700_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_700_cycles feature of this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_700_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 68/100: Battery b3c16 with feature 'mean_grad_last_700_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_700_cycles as this unknown one?'
#     Received response: b1c2, b1c1, b1c0, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_700_cycles of this unidentified battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a similar mean_grad_last_700_cycles to this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 69/100: Battery b3c16 with feature 'slope_last_800_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_800_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_800_cycles feature of this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_800_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 70/100: Battery b3c16 with feature 'mean_grad_last_800_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_800_cycles as this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c0, b1c4...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_800_cycles of this particular battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a similar mean_grad_last_800_cycles to this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 71/100: Battery b3c16 with feature 'slope_last_900_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_900_cycles feature?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_900_cycles feature of this unknown battery?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_900_cycles characteristic?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#
# Processing test case 72/100: Battery b3c16 with feature 'mean_grad_last_900_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_900_cycles as this unknown one?'
#     Received response: b1c1, b1c2, b1c0, b1c4, b1c3....
#   Processing question 2: 'Could you identify batteries that have a mean_grad_last_900_cycles similar to this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c0...
#   Processing question 3: 'Is it possible to locate batteries with a mean_grad_last_900_cycles that matches this unknown battery?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#
# Processing test case 73/100: Battery b3c16 with feature 'slope_last_1000_cycles'
#   Processing question 1: 'Are there any batteries that have a similar slope_last_1000_cycles feature as this one?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c0...
#   Processing question 2: 'Could you identify batteries that match the slope_last_1000_cycles feature of this particular battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Is it possible to locate batteries with a slope_last_1000_cycles feature that is comparable to this one?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 74/100: Battery b3c16 with feature 'mean_grad_last_1000_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_1000_cycles as this unknown one?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#   Processing question 2: 'Could you identify batteries that match the mean_grad_last_1000_cycles of this particular battery?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#   Processing question 3: 'Is it possible to locate batteries with a similar mean_grad_last_1000_cycles to this unknown battery?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#
# Processing test case 75/100: Battery b3c16 with feature 'cycle'
#   Processing question 1: 'Can you identify batteries that have a similar cycle to an unknown one?'
#     Received response: b1c9, b1c9, b1c23, b1c24, b1c41...
#   Processing question 2: 'Are there any batteries that share a similar cycle with an unknown one?'
#     Received response: b1c41, b1c24, b1c24, b1c41, b1c9...
#   Processing question 3: 'Can you locate batteries with a cycle similar to an unknown one?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 76/100: Battery b3c45 with feature 'slope_last_10_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_10_cycles feature as the unknown one?'
#     Received response: b1c0, b1c2, b1c1, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that match the unknown one in terms of the slope_last_10_cycles feature?'
#     Received response: b1c1, b1c3, b1c4, b1c2, b1c0...
# ...
# "MATCH (b:Battery) RETURN b.battery_id, abs(b.slope_last_200_cycles - (-0.0003975352644920349)) as diff ORDER BY diff ASC LIMIT 5 |"
#                                                                                                                                   ^}. Returning empty response for scoring.
#     Received response: ...
#
# Processing test case 83/100: Battery b3c45 with feature 'mean_grad_last_200_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar mean_grad_last_200_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 2: 'Are there any batteries that share the same mean_grad_last_200_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 3: 'Can you locate batteries with a comparable mean_grad_last_200_cycles attribute?'
#     Received response: b1c4, b1c3, b1c2, b1c1, b1c0...
#
# Processing test case 84/100: Battery b3c45 with feature 'slope_last_300_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_300_cycles feature?'
#     Received response: b1c4, b1c3, b1c2, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that match the slope_last_300_cycles feature of this unknown battery?'
#     Received response: b1c4, b1c3, b1c2, b1c1, b1c0...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_300_cycles characteristic?'
#     Received response: b1c4, b1c3, b1c2, b1c1, b1c0...
#
# Processing test case 85/100: Battery b3c45 with feature 'mean_grad_last_300_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_300_cycles as this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c0...
#   Processing question 2: 'Are there any batteries that share the same mean_grad_last_300_cycles as this particular battery?'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 71, offset: 172} for query: 'MATCH (b1:Battery {mean_grad_last_300_cycles: -0.00036169777313868205}) \nWITH b1 \nMATCH (b2:Battery) \nWHERE b2.mean_grad_last_300_cycles = b1.mean_grad_last_300_cycles AND id(b2) <> id(b1) \nRETURN b2.battery_id \nORDER BY abs(b2.mean_grad_last_300_cycles - b1.mean_grad_last_300_cycles) \nLIMIT 5'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 81, offset: 182} for query: 'MATCH (b1:Battery {mean_grad_last_300_cycles: -0.00036169777313868205}) \nWITH b1 \nMATCH (b2:Battery) \nWHERE b2.mean_grad_last_300_cycles = b1.mean_grad_last_300_cycles AND id(b2) <> id(b1) \nRETURN b2.battery_id \nORDER BY abs(b2.mean_grad_last_300_cycles - b1.mean_grad_last_300_cycles) \nLIMIT 5'
#     Received response: I don't know the answer....
#   Processing question 3: 'Could you locate batteries with a similar mean_grad_last_300_cycles to this battery?'
#     Received response: b1c1, b1c2, b1c3, b1c4, b1c0...
#
# Processing test case 86/100: Battery b3c45 with feature 'slope_last_400_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_400_cycles feature?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#   Processing question 2: 'Are there any batteries that match the slope_last_400_cycles feature of this unknown battery?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_400_cycles characteristic?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#
# Processing test case 87/100: Battery b3c45 with feature 'mean_grad_last_400_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar mean_grad_last_400_cycles feature?'
#     Received response: b1c4, b1c2, b1c3, b1c1, b1c0...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_400_cycles feature of this one?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#   Processing question 3: 'Can you locate batteries with a comparable mean_grad_last_400_cycles feature?'
#     Received response: b1c4, b1c1, b1c2, b1c3, b1c0...
#
# Processing test case 88/100: Battery b3c45 with feature 'slope_last_500_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_500_cycles feature?'
#     Received response: b1c38, b1c39, b1c44, b1c45, b1c33....
#   Processing question 2: 'Are there any batteries that match the slope_last_500_cycles feature of this unknown battery?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_500_cycles characteristic?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#
# Processing test case 89/100: Battery b3c45 with feature 'mean_grad_last_500_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_500_cycles as this unknown one?'
#     Received response: b1c4, b1c1, b1c2, b1c0, b1c3...
#   Processing question 2: 'Could you identify batteries that have a mean_grad_last_500_cycles similar to this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c0, b1c4...
#   Processing question 3: 'Is it possible to locate batteries with a similar mean_grad_last_500_cycles to this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#
# Processing test case 90/100: Battery b3c45 with feature 'slope_last_600_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_600_cycles feature?'
# Error invoking chain: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '|': expected an expression, 'FOREACH', 'ORDER BY', 'CALL', 'CREATE', 'LOAD CSV', 'DELETE', 'DETACH', 'FINISH', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REMOVE', 'RETURN', 'SET', 'SKIP', 'UNION', 'UNWIND', 'USE', 'WITH' or <EOF> (line 1, column 131 (offset: 130))
# "MATCH (b:Battery) RETURN b.battery_id, abs(b.slope_last_600_cycles - (-0.00023831049601236978)) as diff ORDER BY diff ASC LIMIT 5 |"
#                                                                                                                                    ^}. Returning empty response for scoring.
#     Received response: ...
#   Processing question 2: 'Are there any batteries that match the slope_last_600_cycles feature of this unknown battery?'
#     Received response: b1c3, b1c0, b1c2, b1c1, b1c4...
#   Processing question 3: 'Can you locate batteries with a similar slope_last_600_cycles characteristic as this unknown battery?'
#     Received response: b1c1, b1c2, b1c0, b1c4, b1c3...
#
# Processing test case 91/100: Battery b3c45 with feature 'mean_grad_last_600_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_600_cycles as this unknown one?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_600_cycles of this particular battery?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#   Processing question 3: 'Could you locate batteries with a similar mean_grad_last_600_cycles to this unknown battery?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#
# Processing test case 92/100: Battery b3c45 with feature 'slope_last_700_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_700_cycles feature?'
#     Received response: To identify batteries with similar slope_last_700_...
#   Processing question 2: 'Are there any batteries that share the same slope_last_700_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_700_cycles attribute?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 93/100: Battery b3c45 with feature 'mean_grad_last_700_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_700_cycles as this unknown battery?'
#     Received response: b1c1, b1c2, b1c3, b1c0, b1c4...
#   Processing question 2: 'Are there any batteries that share the same mean_grad_last_700_cycles as this particular battery?'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 71, offset: 172} for query: 'MATCH (b1:Battery {mean_grad_last_700_cycles: -0.00021437951496669226}) \nWITH b1 \nMATCH (b2:Battery) \nWHERE b2.mean_grad_last_700_cycles = b1.mean_grad_last_700_cycles AND id(b2) <> id(b1) \nRETURN b2.battery_id \nORDER BY abs(b2.mean_grad_last_700_cycles - b1.mean_grad_last_700_cycles) \nLIMIT 5'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 81, offset: 182} for query: 'MATCH (b1:Battery {mean_grad_last_700_cycles: -0.00021437951496669226}) \nWITH b1 \nMATCH (b2:Battery) \nWHERE b2.mean_grad_last_700_cycles = b1.mean_grad_last_700_cycles AND id(b2) <> id(b1) \nRETURN b2.battery_id \nORDER BY abs(b2.mean_grad_last_700_cycles - b1.mean_grad_last_700_cycles) \nLIMIT 5'
#     Received response: I don't know the answer....
#   Processing question 3: 'Can you locate batteries with a mean_grad_last_700_cycles that matches this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 94/100: Battery b3c45 with feature 'slope_last_800_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_800_cycles feature?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_800_cycles feature of this unknown battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_800_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 95/100: Battery b3c45 with feature 'mean_grad_last_800_cycles'
#   Processing question 1: 'Can you identify batteries that have similar mean_grad_last_800_cycles as this unknown one?'
# Error invoking chain: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '|': expected an expression, 'FOREACH', 'ORDER BY', 'CALL', 'CREATE', 'LOAD CSV', 'DELETE', 'DETACH', 'FINISH', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REMOVE', 'RETURN', 'SET', 'SKIP', 'UNION', 'UNWIND', 'USE', 'WITH' or <EOF> (line 1, column 222 (offset: 221))
# "MATCH (b:Battery) WHERE abs(b.mean_grad_last_800_cycles - (-0.00019524380564689636)) < 0.0001 RETURN b.battery_id, b.mean_grad_last_800_cycles ORDER BY abs(b.mean_grad_last_800_cycles - (-0.00019524380564689636)) LIMIT 5 | 1, 2, 3, 4, 5"
#                                                                                                                                                                                                                               ^}. Returning empty response for scoring.
#     Received response: ...
#   Processing question 2: 'Are there any batteries that match the mean_grad_last_800_cycles of this unidentified battery?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#   Processing question 3: 'Can you locate batteries with a similar mean_grad_last_800_cycles to this mystery battery?'
#     Received response: b1c1, b1c2, b1c3, b1c0, b1c4...
#
# Processing test case 96/100: Battery b3c45 with feature 'slope_last_900_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_900_cycles feature?'
# Error invoking chain: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '|': expected an expression, 'FOREACH', 'ORDER BY', 'CALL', 'CREATE', 'LOAD CSV', 'DELETE', 'DETACH', 'FINISH', 'INSERT', 'LIMIT', 'MATCH', 'MERGE', 'NODETACH', 'OFFSET', 'OPTIONAL', 'REMOVE', 'RETURN', 'SET', 'SKIP', 'UNION', 'UNWIND', 'USE', 'WITH' or <EOF> (line 1, column 129 (offset: 128))
# "MATCH (b:Battery) RETURN b.battery_id, abs(b.slope_last_900_cycles - (-0.000179978609085083)) as diff ORDER BY diff ASC LIMIT 5 |"
#                                                                                                                                  ^}. Returning empty response for scoring.
#     Received response: ...
#   Processing question 2: 'Are there any batteries that share the same slope_last_900_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c3, b1c4...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_900_cycles attribute?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#
# Processing test case 97/100: Battery b3c45 with feature 'mean_grad_last_900_cycles'
#   Processing question 1: 'Are there any batteries that have similar features to one with mean_grad_last_900_cycles?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#   Processing question 2: 'Could you identify batteries that are comparable to one with mean_grad_last_900_cycles?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#   Processing question 3: 'Is it possible to locate batteries that match one with mean_grad_last_900_cycles?'
#     Received response: b1c0, b1c2, b1c1, b1c4, b1c3...
#
# Processing test case 98/100: Battery b3c45 with feature 'slope_last_1000_cycles'
#   Processing question 1: 'Can you identify batteries that have a similar slope_last_1000_cycles feature?'
#     Received response: b1c1, b1c0, b1c2, b1c4, b1c3...
#   Processing question 2: 'Are there any batteries that match the slope_last_1000_cycles feature of this one?'
#     Received response: b1c0, b1c1, b1c4, b1c2, b1c3...
#   Processing question 3: 'Can you locate batteries with a comparable slope_last_1000_cycles characteristic?'
#     Received response: b1c0, b1c1, b1c2, b1c4, b1c3...
#
# Processing test case 99/100: Battery b3c45 with feature 'mean_grad_last_1000_cycles'
#   Processing question 1: 'Are there any batteries that have similar mean_grad_last_1000_cycles as this unknown one?'
#     Received response: b1c2, b1c4, b1c0, b1c1, b1c3...
#   Processing question 2: 'Could you identify batteries that have a mean_grad_last_1000_cycles similar to this unknown battery?'
#     Received response: b1c1, b1c0, b1c4, b1c2, b1c3...
#   Processing question 3: 'Is it possible to locate batteries with a mean_grad_last_1000_cycles that matches this unknown battery?'
#     Received response: b1c2, b1c4, b1c0, b1c1, b1c3...
#
# Processing test case 100/100: Battery b3c45 with feature 'cycle'
#   Processing question 1: 'Can you identify batteries that are similar to one with a cycle feature?'
#     Received response: b1c0, b1c3, b1c2, b1c1, b1c4...
#   Processing question 2: 'Are there any batteries comparable to one with a cycle?'
# Error invoking chain: {code: Neo.ClientError.Statement.SyntaxError} {message: Variable `b` not defined (line 32, column 8 (offset: 1918))
# "RETURN b.battery_id"
#         ^}. Returning empty response for scoring.
#     Received response: ...
#   Processing question 3: 'Can you locate batteries that have a similar cycle feature?'
#     Received response: b1c41, b1c24, b1c41, b1c24, b1c9, b1c23, b1c5, b1c...
#
# LLM responses saved to /home/jaf/battery-lifespan-kg/eval/llm_response_for_evaluator_question.csv.csv

# %% [markdown]
# ## Evaluate

# %%
import re
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Configurable parameter
TOP_K = 5  # Change this to evaluate top-k

def extract_battery_ids(text):
    """
    Extract battery IDs matching the pattern: b{number}c{number}
    (returns a list in left-to-right order)
    """
    return re.findall(r'\bb\d+c\d+\b', text, flags=re.IGNORECASE)

def evaluate_query(ground_truth, pred_text, k):
    """
    For a single query, extract predicted battery IDs from the LLM response,
    ensure we have at least k predictions (pad with empty strings if needed),
    and then evaluate:
      - Binary outcome: 1 if the ground truth appears in the top-k, else 0.
      - Reciprocal Rank (RR): 1/(rank) if found; otherwise 0.
    """
    preds = extract_battery_ids(pred_text)
    # Pad with empty strings if fewer than k predictions
    if len(preds) < k:
        preds += [""] * (k - len(preds))
    found = 0
    rr = 0
    for i, p in enumerate(preds[:k]):
        if p.strip().lower() == ground_truth.strip().lower():
            found = 1
            rr = 1.0 / (i + 1)
            break
    return found, rr

# Load ground truth CSV and predicted responses CSV
gt_df = pd.read_csv("/home/jaf/battery-lifespan-kg/eval/evaluator_question.csv")
pred_df = pd.read_csv("/home/jaf/battery-lifespan-kg/eval/llm_response_for_evaluator_question_short.csv")

# Merge the two dataframes based on test battery ID and query feature
merged_df = pd.merge(gt_df, pred_df, on=["TEST_BATTERY_ID", "TEST_BATTERY_QUERY_FEATURE"], how="inner")

# We assume there are three sample questions per row.
num_questions = 3
binary_labels = []  # 1 if correct (ground truth in top-k), else 0
rr_list = []       # Reciprocal Rank for each query

# Loop through each test case and each question
for idx, row in merged_df.iterrows():
    for i in range(1, num_questions + 1):
        gt_col = f"{i}_Most_Similar_Battery_ID"
        pred_col = f"q{i}_raw_response"
        if pd.isna(row.get(gt_col)):
            continue  # Skip if ground truth is not available
        ground_truth = str(row[gt_col])
        pred_text = str(row.get(pred_col, ""))
        label, rr = evaluate_query(ground_truth, pred_text, TOP_K)
        binary_labels.append(label)
        rr_list.append(rr)

# For our binary evaluation, ground truth labels for each query are all 1 (we expect it to be found)
y_true = [1] * len(binary_labels)
y_pred = binary_labels

# Use scikit-learn to compute metrics
topk_accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, zero_division=0)
recall = recall_score(y_true, y_pred, zero_division=0)
f1 = f1_score(y_true, y_pred, zero_division=0)
mrr = sum(rr_list) / len(rr_list) if rr_list else 0

print("Evaluation Metrics:")
print("Top-{} Accuracy: {:.2f}%".format(TOP_K, topk_accuracy * 100))
print("Mean Reciprocal Rank (MRR): {:.3f}".format(mrr))
print("Precision@{}: {:.3f}".format(TOP_K, precision))
print("Recall@{}: {:.3f}".format(TOP_K, recall))
print("F1 Score: {:.3f}".format(f1))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 38
#      36 # Load ground truth CSV and predicted responses CSV
#      37 gt_df = pd.read_csv("/home/jaf/battery-lifespan-kg/eval/evaluator_question.csv")
# ---> 38 pred_df = pd.read_csv("/home/jaf/battery-lifespan-kg/eval/llm_response_for_evaluator_question_short.csv")
#      40 # Merge the two dataframes based on test battery ID and query feature
#      41 merged_df = pd.merge(gt_df, pred_df, on=["TEST_BATTERY_ID", "TEST_BATTERY_QUERY_FEATURE"], how="inner")
#
# File ~/anaconda3/envs/tserie/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/tserie/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/anaconda3/envs/tserie/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/tserie/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/anaconda3/envs/tserie/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jaf/battery-lifespan-kg/eval/llm_response_for_evaluator_question_short.csv'

# %%
import re
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Configurable parameter
TOP_K = 1  # Evaluate top-1; set to 3 if you want top-3, etc.

def extract_battery_ids(text):
    """
    Extract battery IDs matching the pattern b{number}c{number} in left-to-right order.
    For example, from "b1c1, b1c3" it returns ["b1c1", "b1c3"].
    """
    return re.findall(r'\bb\d+c\d+\b', text, flags=re.IGNORECASE)

def evaluate_query(ground_truth, pred_text, k):
    """
    For a single query:
      - Extract battery IDs from the predicted text.
      - If fewer than k predictions are returned, pad with empty strings.
      - Check if the ground truth is within the top k predictions.
      - Calculate the reciprocal rank (1/(rank position)) if found, or 0 if not.
      
    Returns:
      found (binary: 1 if correct answer is found in top-k, else 0),
      rr (reciprocal rank)
    """
    preds = extract_battery_ids(pred_text)
    if len(preds) < k:
        preds += [""] * (k - len(preds))
    found = 0
    rr = 0
    for idx, p in enumerate(preds[:k]):
        if p.strip().lower() == ground_truth.strip().lower():
            found = 1
            rr = 1.0 / (idx + 1)
            break
    return found, rr

# Load the ground truth and predicted responses CSV files.
gt_df = pd.read_csv("/home/jaf/battery-lifespan-kg/eval/evaluator_question.csv")
pred_df = pd.read_csv("/home/jaf/battery-lifespan-kg/eval/llm_response_for_evaluator_question.csv.csv")

# Merge dataframes on TEST_BATTERY_ID and TEST_BATTERY_QUERY_FEATURE.
merged_df = pd.merge(gt_df, pred_df, on=["TEST_BATTERY_ID", "TEST_BATTERY_QUERY_FEATURE"], how="inner")

# We'll assume there are three sample questions per row.
num_questions = 3

# Collect metrics for each query along with its feature.
records = []  # Each record: feature, binary label, and reciprocal rank (rr)

for idx, row in merged_df.iterrows():
    feature = row["TEST_BATTERY_QUERY_FEATURE"]
    for i in range(1, num_questions + 1):
        gt_col = f"{i}_Most_Similar_Battery_ID"  # Ground truth column for query i
        pred_col = f"q{i}_raw_response"            # LLM response column for query i
        if pd.isna(row.get(gt_col)):
            continue  # Skip if ground truth is missing
        ground_truth = str(row[gt_col])
        pred_text = str(row.get(pred_col, ""))
        label, rr = evaluate_query(ground_truth, pred_text, TOP_K)
        records.append({
            "feature": feature,
            "label": label,
            "rr": rr
        })

# Convert records to a DataFrame.
eval_df = pd.DataFrame(records)

# Now, compute and print metrics for each feature.
print("Per-feature evaluation metrics:\n")
for feature, group in eval_df.groupby("feature"):
    y_true = [1] * len(group)  # We expect the ground truth to be present in each query.
    y_pred = group["label"].tolist()
    
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    mrr = group["rr"].mean()
    
    print(f"Feature: {feature}")
    print(f"  Top-{TOP_K} Accuracy: {acc * 100:.2f}%")
    print(f"  Precision@{TOP_K}: {prec:.3f}")
    print(f"  Recall@{TOP_K}: {rec:.3f}")
    print(f"  F1 Score: {f1:.3f}")
    print(f"  Mean Reciprocal Rank (MRR): {mrr:.3f}\n")
# Out:
# Per-feature evaluation metrics:
#
# Feature: cycle
#   Top-1 Accuracy: 25.00%
#   Precision@1: 1.000
#   Recall@1: 0.250
#   F1 Score: 0.400
#   Mean Reciprocal Rank (MRR): 0.250
#
# Feature: mean_grad_last_1000_cycles
#   Top-1 Accuracy: 25.00%
#   Precision@1: 1.000
#   Recall@1: 0.250
#   F1 Score: 0.400
#   Mean Reciprocal Rank (MRR): 0.250
#
# Feature: mean_grad_last_100_cycles
#   Top-1 Accuracy: 8.33%
#   Precision@1: 1.000
#   Recall@1: 0.083
#   F1 Score: 0.154
#   Mean Reciprocal Rank (MRR): 0.083
#
# Feature: mean_grad_last_10_cycles
#   Top-1 Accuracy: 16.67%
#   Precision@1: 1.000
#   Recall@1: 0.167
#   F1 Score: 0.286
#   Mean Reciprocal Rank (MRR): 0.167
#
# Feature: mean_grad_last_200_cycles
#   Top-1 Accuracy: 16.67%
#   Precision@1: 1.000
#   Recall@1: 0.167
#   F1 Score: 0.286
#   Mean Reciprocal Rank (MRR): 0.167
#
# Feature: mean_grad_last_300_cycles
#   Top-1 Accuracy: 16.67%
#   Precision@1: 1.000
#   Recall@1: 0.167
#   F1 Score: 0.286
#   Mean Reciprocal Rank (MRR): 0.167
#
# Feature: mean_grad_last_400_cycles
#   Top-1 Accuracy: 8.33%
#   Precision@1: 1.000
#   Recall@1: 0.083
#   F1 Score: 0.154
#   Mean Reciprocal Rank (MRR): 0.083
#
# Feature: mean_grad_last_500_cycles
#   Top-1 Accuracy: 16.67%
#   Precision@1: 1.000
#   Recall@1: 0.167
#   F1 Score: 0.286
#   Mean Reciprocal Rank (MRR): 0.167
#
# Feature: mean_grad_last_50_cycles
#   Top-1 Accuracy: 16.67%
#   Precision@1: 1.000
#   Recall@1: 0.167
#   F1 Score: 0.286
#   Mean Reciprocal Rank (MRR): 0.167
#
# Feature: mean_grad_last_600_cycles
#   Top-1 Accuracy: 33.33%
#   Precision@1: 1.000
#   Recall@1: 0.333
#   F1 Score: 0.500
#   Mean Reciprocal Rank (MRR): 0.333
#
# Feature: mean_grad_last_700_cycles
#   Top-1 Accuracy: 25.00%
#   Precision@1: 1.000
#   Recall@1: 0.250
#   F1 Score: 0.400
#   Mean Reciprocal Rank (MRR): 0.250
#
# Feature: mean_grad_last_800_cycles
#   Top-1 Accuracy: 16.67%
#   Precision@1: 1.000
#   Recall@1: 0.167
#   F1 Score: 0.286
#   Mean Reciprocal Rank (MRR): 0.167
#
# Feature: mean_grad_last_900_cycles
#   Top-1 Accuracy: 25.00%
#   Precision@1: 1.000
#   Recall@1: 0.250
#   F1 Score: 0.400
#   Mean Reciprocal Rank (MRR): 0.250
#
# Feature: slope_last_1000_cycles
#   Top-1 Accuracy: 25.00%
#   Precision@1: 1.000
#   Recall@1: 0.250
#   F1 Score: 0.400
#   Mean Reciprocal Rank (MRR): 0.250
#
# Feature: slope_last_100_cycles
#   Top-1 Accuracy: 16.67%
#   Precision@1: 1.000
#   Recall@1: 0.167
#   F1 Score: 0.286
#   Mean Reciprocal Rank (MRR): 0.167
#
# Feature: slope_last_10_cycles
#   Top-1 Accuracy: 33.33%
#   Precision@1: 1.000
#   Recall@1: 0.333
#   F1 Score: 0.500
#   Mean Reciprocal Rank (MRR): 0.333
#
# Feature: slope_last_200_cycles
#   Top-1 Accuracy: 8.33%
#   Precision@1: 1.000
#   Recall@1: 0.083
#   F1 Score: 0.154
#   Mean Reciprocal Rank (MRR): 0.083
#
# Feature: slope_last_300_cycles
#   Top-1 Accuracy: 25.00%
#   Precision@1: 1.000
#   Recall@1: 0.250
#   F1 Score: 0.400
#   Mean Reciprocal Rank (MRR): 0.250
#
# Feature: slope_last_400_cycles
#   Top-1 Accuracy: 25.00%
#   Precision@1: 1.000
#   Recall@1: 0.250
#   F1 Score: 0.400
#   Mean Reciprocal Rank (MRR): 0.250
#
# Feature: slope_last_500_cycles
#   Top-1 Accuracy: 8.33%
#   Precision@1: 1.000
#   Recall@1: 0.083
#   F1 Score: 0.154
#   Mean Reciprocal Rank (MRR): 0.083
#
# Feature: slope_last_50_cycles
#   Top-1 Accuracy: 8.33%
#   Precision@1: 1.000
#   Recall@1: 0.083
#   F1 Score: 0.154
#   Mean Reciprocal Rank (MRR): 0.083
#
# Feature: slope_last_600_cycles
#   Top-1 Accuracy: 8.33%
#   Precision@1: 1.000
#   Recall@1: 0.083
#   F1 Score: 0.154
#   Mean Reciprocal Rank (MRR): 0.083
#
# Feature: slope_last_700_cycles
#   Top-1 Accuracy: 8.33%
#   Precision@1: 1.000
#   Recall@1: 0.083
#   F1 Score: 0.154
#   Mean Reciprocal Rank (MRR): 0.083
#
# Feature: slope_last_800_cycles
#   Top-1 Accuracy: 0.00%
#   Precision@1: 0.000
#   Recall@1: 0.000
#   F1 Score: 0.000
#   Mean Reciprocal Rank (MRR): 0.000
#
# Feature: slope_last_900_cycles
#   Top-1 Accuracy: 0.00%
#   Precision@1: 0.000
#   Recall@1: 0.000
#   F1 Score: 0.000
#   Mean Reciprocal Rank (MRR): 0.000
