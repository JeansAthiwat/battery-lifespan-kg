# %% [markdown]
# # Type B metric

# %%
import os
import numpy as np
import pandas as pd
import glob

battery_paths = glob.glob("../resources/testset/*.txt")
K_VALUES = [10, 50, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

def load_trimmed_battery(file_path):
    with open(file_path, 'r') as f:
        lines = [line.strip().rstrip(',') for line in f if line.strip()]
        values = [float(v) for v in lines]
    trimmed = np.trim_zeros(np.array(values), 'b')
    return trimmed

def extract_features(trimmed_q_d_n):
    total_cycles = len(trimmed_q_d_n)
    features = {'total_cycles': total_cycles}

    if total_cycles > 1:
        for k in K_VALUES:
            if( total_cycles < k):
                continue

            # First K (or fewer) cycles
            slope_first = (trimmed_q_d_n[k-1] - trimmed_q_d_n[0]) / k
            grad_first = np.gradient(trimmed_q_d_n[:k], 1)
            mean_grad_first = float(np.mean(grad_first))

            # Last K (or fewer) cycles
            slope_last = (trimmed_q_d_n[-1] - trimmed_q_d_n[-k]) / k
            grad_last = np.gradient(trimmed_q_d_n[-k:], 1)
            mean_grad_last = float(np.mean(grad_last))

            features[f'slope_first_{k}_cycles'] = slope_first
            features[f'slope_last_{k}_cycles'] = slope_last
            features[f'mean_grad_first_{k}_cycles'] = mean_grad_first
            features[f'mean_grad_last_{k}_cycles'] = mean_grad_last

    return features

# Run extraction for all files
all_features = []

for path in battery_paths:
    trimmed = load_trimmed_battery(path)
    features = extract_features(trimmed)
    features['battery_id'] = os.path.basename(path).replace('.txt', '')
    all_features.append(features)

# Convert to DataFrame to view
df_features = pd.DataFrame(all_features)
print(df_features.shape)
print(df_features)
# Out:
# (40, 50)
#     total_cycles  slope_first_10_cycles  slope_last_10_cycles  \
# 0           1147               0.000254             -0.000392
# 1            826               0.000481             -0.000939
# 2            941               0.000411             -0.001080
# 3            877               0.000314             -0.000773
# 4            732               0.000336             -0.001117
# 5            990               0.000413             -0.000837
# 6           1047               0.000344             -0.000736
# 7           1010               0.000385             -0.000808
# 8            851               0.000458             -0.000725
# 9            668               0.000043             -0.000468
# 10           818               0.000328             -0.000780
# 11          1094               0.000260             -0.000477
# 12           797               0.000507             -0.000847
# 13           936               0.000423             -0.000951
# 14           859               0.000469             -0.000971
# 15           814               0.000376             -0.000893
# 16          1837               0.000382             -0.000230
# 17           829               0.000427             -0.001025
# 18           829               0.000363             -0.000803
# 19           933               0.000337             -0.000773
# 20          1156               0.000326             -0.000447
# 21          1643               0.000341             -0.000318
# 22          1802               0.000253             -0.000250
# 23          1316               0.000361             -0.000406
# 24          1639               0.000305             -0.000301
# 25          1040               0.000441             -0.000710
# 26          1079               0.000343             -0.000438
# 27           817               0.000471             -0.000863
# 28          1029               0.000398             -0.000565
# 29           542               0.000118             -0.000629
# 30          1116               0.000283             -0.000492
# 31           924               0.000265             -0.001095
# 32          1159               0.000380             -0.000527
# 33          1003               0.000337             -0.001161
# 34           787               0.000457             -0.000751
# 35          1064               0.000404             -0.000629
# 36           773               0.000074             -0.000853
# 37          1049               0.000280             -0.000498
# 38           859               0.000465             -0.000766
# 39          1285               0.000304             -0.000568
#
#     mean_grad_first_10_cycles  mean_grad_last_10_cycles  \
# 0                    0.000288                 -0.000431
# 1                    0.000537                 -0.001004
# 2                    0.000473                 -0.001158
# 3                    0.000349                 -0.000830
# 4                    0.000376                 -0.001194
# 5                    0.000465                 -0.000898
# 6                    0.000404                 -0.000795
# 7                    0.000438                 -0.000869
# 8                    0.000526                 -0.000779
# 9                    0.000067                 -0.000500
# 10                   0.000370                 -0.000837
# 11                   0.000308                 -0.000512
# 12                   0.000577                 -0.000910
# 13                   0.000490                 -0.001021
# 14                   0.000526                 -0.001045
# 15                   0.000446                 -0.000964
# 16                   0.000437                 -0.000225
# 17                   0.000492                 -0.001101
# 18                   0.000439                 -0.000868
# 19                   0.000389                 -0.000829
# 20                   0.000391                 -0.000485
# 21                   0.000403                 -0.000341
# 22                   0.000297                 -0.000288
# 23                   0.000422                 -0.000435
# 24                   0.000334                 -0.000323
# 25                   0.000511                 -0.000766
# 26                   0.000396                 -0.000472
# 27                   0.000550                 -0.000927
# 28                   0.000454                 -0.000614
# 29                   0.000141                 -0.000685
# 30                   0.000324                 -0.000530
# 31                   0.000280                 -0.001172
# 32                   0.000450                 -0.000564
# 33                   0.000397                 -0.001246
# 34                   0.000535                 -0.000813
# 35                   0.000442                 -0.000677
# 36                   0.000073                 -0.000910
# 37                   0.000314                 -0.000539
# 38                   0.000532                 -0.000823
# 39                   0.000346                 -0.000607
#
#     slope_first_50_cycles  slope_last_50_cycles  mean_grad_first_50_cycles  \
# 0                0.000034             -0.000581                   0.000038
# 1                0.000115             -0.001223                   0.000125
# 2                0.000102             -0.001374                   0.000113
# 3                0.000065             -0.001009                   0.000074
# 4                0.000072             -0.001391                   0.000077
# 5                0.000104             -0.001049                   0.000117
# 6                0.000079             -0.001006                   0.000089
# 7                0.000088             -0.001099                   0.000097
# 8                0.000099             -0.001024                   0.000111
# 9               -0.000165             -0.000565                  -0.000160
# 10               0.000058             -0.001044                   0.000066
# 11               0.000044             -0.000626                   0.000051
# 12               0.000108             -0.001068                   0.000119
# 13               0.000093             -0.001203                   0.000106
# 14               0.000122             -0.001183                   0.000132
# 15               0.000080             -0.001287                   0.000092
# 16               0.000079             -0.000430                   0.000089
# 17               0.000098             -0.001319                   0.000108
# 18               0.000068             -0.001074                   0.000083
# 19               0.000069             -0.001089                   0.000079
# 20               0.000049             -0.000613                   0.000062
# 21               0.000084             -0.000472                   0.000096
# 22               0.000067             -0.000416                   0.000075
# 23               0.000043             -0.000553                   0.000054
# 24               0.000068             -0.000435                   0.000072
# 25               0.000094             -0.000981                   0.000104
# 26               0.000081             -0.000700                   0.000093
# 27               0.000102             -0.001085                   0.000116
# 28               0.000089             -0.000783                   0.000098
# 29              -0.000124             -0.000683                  -0.000121
# 30               0.000056             -0.000730                   0.000063
# 31               0.000046             -0.001377                   0.000047
# 32               0.000068             -0.000632                   0.000080
# 33               0.000068             -0.001319                   0.000080
# 34               0.000112             -0.001011                   0.000125
# 35               0.000078             -0.000812                   0.000088
# 36              -0.000111             -0.000843                  -0.000113
# 37               0.000065             -0.000733                   0.000072
# 38               0.000116             -0.001029                   0.000128
# 39               0.000061             -0.000760                   0.000069
#
#     mean_grad_last_50_cycles  slope_first_100_cycles  ...  \
# 0                  -0.000587               -0.000005  ...
# 1                  -0.001236                0.000049  ...
# 2                  -0.001387                0.000043  ...
# 3                  -0.001018                0.000016  ...
# 4                  -0.001404                0.000023  ...
# 5                  -0.001059                0.000043  ...
# 6                  -0.001017                0.000033  ...
# 7                  -0.001111                0.000029  ...
# 8                  -0.001035                0.000035  ...
# 9                  -0.000571               -0.000182  ...
# 10                 -0.001054                0.000010  ...
# 11                 -0.000632                0.000006  ...
# 12                 -0.001078                0.000036  ...
# 13                 -0.001215                0.000035  ...
# 14                 -0.001193                0.000048  ...
# 15                 -0.001300                0.000027  ...
# 16                 -0.000438                0.000020  ...
# 17                 -0.001331                0.000034  ...
# 18                 -0.001084                0.000018  ...
# 19                 -0.001101                0.000024  ...
# 20                 -0.000618                0.000002  ...
# 21                 -0.000478                0.000033  ...
# 22                 -0.000423                0.000023  ...
# 23                 -0.000558                0.000012  ...
# 24                 -0.000439                0.000020  ...
# 25                 -0.000990                0.000041  ...
# 26                 -0.000708                0.000015  ...
# 27                 -0.001094                0.000031  ...
# 28                 -0.000791                0.000035  ...
# 29                 -0.000689               -0.000173  ...
# 30                 -0.000737                0.000013  ...
# 31                 -0.001390                0.000004  ...
# 32                 -0.000639                0.000013  ...
# 33                 -0.001343                0.000018  ...
# 34                 -0.001022                0.000050  ...
# 35                 -0.000822                0.000023  ...
# 36                 -0.000849               -0.000140  ...
# 37                 -0.000739                0.000021  ...
# 38                 -0.001039                0.000044  ...
# 39                 -0.000768                0.000015  ...
#
#     mean_grad_last_800_cycles  slope_first_900_cycles  slope_last_900_cycles  \
# 0                   -0.000220               -0.000064              -0.000201
# 1                   -0.000213                     NaN                    NaN
# 2                   -0.000239               -0.000144              -0.000215
# 3                   -0.000237                     NaN                    NaN
# 4                         NaN                     NaN                    NaN
# 5                   -0.000225               -0.000100              -0.000203
# 6                   -0.000235               -0.000070              -0.000212
# 7                   -0.000232               -0.000090              -0.000210
# 8                   -0.000230                     NaN                    NaN
# 9                         NaN                     NaN                    NaN
# 10                  -0.000237                     NaN                    NaN
# 11                  -0.000219               -0.000078              -0.000200
# 12                        NaN                     NaN                    NaN
# 13                  -0.000237               -0.000158              -0.000213
# 14                  -0.000246                     NaN                    NaN
# 15                  -0.000234                     NaN                    NaN
# 16                  -0.000196               -0.000026              -0.000179
# 17                  -0.000234                     NaN                    NaN
# 18                  -0.000217                     NaN                    NaN
# 19                  -0.000243               -0.000174              -0.000218
# 20                  -0.000224               -0.000061              -0.000205
# 21                  -0.000199               -0.000033              -0.000184
# 22                  -0.000195               -0.000029              -0.000180
# 23                  -0.000210               -0.000044              -0.000192
# 24                  -0.000192               -0.000034              -0.000175
# 25                  -0.000237               -0.000076              -0.000213
# 26                  -0.000222               -0.000064              -0.000201
# 27                  -0.000236                     NaN                    NaN
# 28                  -0.000237               -0.000106              -0.000215
# 29                        NaN                     NaN                    NaN
# 30                  -0.000218               -0.000060              -0.000199
# 31                  -0.000220               -0.000158              -0.000200
# 32                  -0.000212               -0.000055              -0.000194
# 33                  -0.000216               -0.000073              -0.000195
# 34                        NaN                     NaN                    NaN
# 35                  -0.000225               -0.000071              -0.000205
# 36                        NaN                     NaN                    NaN
# 37                  -0.000235               -0.000094              -0.000214
# 38                  -0.000239                     NaN                    NaN
# 39                  -0.000205               -0.000042              -0.000187
#
#     mean_grad_first_900_cycles  mean_grad_last_900_cycles  \
# 0                    -0.000064                  -0.000201
# 1                          NaN                        NaN
# 2                    -0.000144                  -0.000215
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# 5                    -0.000100                  -0.000204
# 6                    -0.000070                  -0.000212
# 7                    -0.000090                  -0.000210
# 8                          NaN                        NaN
# 9                          NaN                        NaN
# 10                         NaN                        NaN
# 11                   -0.000078                  -0.000200
# 12                         NaN                        NaN
# 13                   -0.000158                  -0.000213
# 14                         NaN                        NaN
# 15                         NaN                        NaN
# 16                   -0.000025                  -0.000179
# 17                         NaN                        NaN
# 18                         NaN                        NaN
# 19                   -0.000174                  -0.000218
# 20                   -0.000061                  -0.000205
# 21                   -0.000032                  -0.000184
# 22                   -0.000029                  -0.000180
# 23                   -0.000044                  -0.000192
# 24                   -0.000034                  -0.000175
# 25                   -0.000076                  -0.000213
# 26                   -0.000064                  -0.000201
# 27                         NaN                        NaN
# 28                   -0.000106                  -0.000215
# 29                         NaN                        NaN
# 30                   -0.000059                  -0.000199
# 31                   -0.000159                  -0.000200
# 32                   -0.000054                  -0.000194
# 33                   -0.000073                  -0.000195
# 34                         NaN                        NaN
# 35                   -0.000071                  -0.000205
# 36                         NaN                        NaN
# 37                   -0.000094                  -0.000214
# 38                         NaN                        NaN
# 39                   -0.000042                  -0.000187
#
#     slope_first_1000_cycles  slope_last_1000_cycles  \
# 0                 -0.000096               -0.000186
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# 5                       NaN                     NaN
# 6                 -0.000140               -0.000193
# 7                 -0.000177               -0.000190
# 8                       NaN                     NaN
# 9                       NaN                     NaN
# 10                      NaN                     NaN
# 11                -0.000122               -0.000183
# 12                      NaN                     NaN
# 13                      NaN                     NaN
# 14                      NaN                     NaN
# 15                      NaN                     NaN
# 16                -0.000028               -0.000166
# 17                      NaN                     NaN
# 18                      NaN                     NaN
# 19                      NaN                     NaN
# 20                -0.000095               -0.000189
# 21                -0.000037               -0.000170
# 22                -0.000032               -0.000167
# 23                -0.000051               -0.000177
# 24                -0.000036               -0.000162
# 25                -0.000148               -0.000193
# 26                -0.000123               -0.000184
# 27                      NaN                     NaN
# 28                -0.000168               -0.000195
# 29                      NaN                     NaN
# 30                -0.000096               -0.000183
# 31                      NaN                     NaN
# 32                -0.000085               -0.000179
# 33                -0.000173               -0.000177
# 34                      NaN                     NaN
# 35                -0.000132               -0.000187
# 36                      NaN                     NaN
# 37                -0.000155               -0.000195
# 38                      NaN                     NaN
# 39                -0.000046               -0.000173
#
#     mean_grad_first_1000_cycles  mean_grad_last_1000_cycles  battery_id
# 0                     -0.000096                   -0.000186       b3c18
# 1                           NaN                         NaN       b3c24
# 2                           NaN                         NaN       b3c44
# 3                           NaN                         NaN       b3c15
# 4                           NaN                         NaN       b3c31
# 5                           NaN                         NaN       b3c25
# 6                     -0.000140                   -0.000193       b3c43
# 7                     -0.000177                   -0.000190        b3c0
# 8                           NaN                         NaN       b3c27
# 9                           NaN                         NaN        b3c6
# 10                          NaN                         NaN       b3c11
# 11                    -0.000122                   -0.000184       b3c35
# 12                          NaN                         NaN       b3c40
# 13                          NaN                         NaN       b3c30
# 14                          NaN                         NaN       b3c14
# 15                          NaN                         NaN       b3c20
# 16                    -0.000027                   -0.000166        b3c7
# 17                          NaN                         NaN        b3c8
# 18                          NaN                         NaN        b3c5
# 19                          NaN                         NaN       b3c12
# 20                    -0.000095                   -0.000189       b3c19
# 21                    -0.000036                   -0.000170       b3c42
# 22                    -0.000032                   -0.000167       b3c45
# 23                    -0.000050                   -0.000177       b3c17
# 24                    -0.000036                   -0.000162       b3c16
# 25                    -0.000148                   -0.000193        b3c9
# 26                    -0.000123                   -0.000184       b3c10
# 27                          NaN                         NaN       b3c13
# 28                    -0.000168                   -0.000195       b3c26
# 29                          NaN                         NaN       b3c28
# 30                    -0.000096                   -0.000183        b3c3
# 31                          NaN                         NaN       b3c36
# 32                    -0.000084                   -0.000179       b3c34
# 33                    -0.000173                   -0.000176       b3c22
# 34                          NaN                         NaN       b3c41
# 35                    -0.000132                   -0.000187        b3c1
# 36                          NaN                         NaN       b3c21
# 37                    -0.000155                   -0.000195        b3c4
# 38                          NaN                         NaN       b3c29
# 39                    -0.000046                   -0.000173       b3c33
#
# [40 rows x 50 columns]

# %% [markdown]
# # get ground truth for each battery (and feature)

# %%
import os
import ast
import numpy as np
import pandas as pd
from glob import glob

# ─── Settings ───────────────────────────────────────────────────
DATA_DIR = "../resources/raw"
TOP_K = 1

# ─── Load & Trim ─────────────────────────────────────────────────
def load_trimmed_battery(file_path):
    with open(file_path, 'r') as f:
        values = []
        for line in f:
            line = line.strip().rstrip(',')
            if not line:
                continue
            if line.startswith('[') and line.endswith(']'):
                try:
                    values.extend(ast.literal_eval(line))
                except Exception as e:
                    print(f"⚠️ Failed to parse list in {file_path}: {line}")
            else:
                try:
                    values.append(float(line))
                except ValueError:
                    print(f"⚠️ Invalid float in {file_path}: {line}")
        return np.trim_zeros(np.array(values), 'b')


# ─── Query Batteries ─────────────────────────────────────────────
query_paths = battery_paths
query_features = {}
for path in query_paths:
    battery_id = os.path.basename(path).replace(".txt", "")
    trimmed = load_trimmed_battery(path)
    feats = extract_features(trimmed)
    query_features[battery_id] = feats

# ─── Candidate Batteries (Compare Pool) ──────────────────────────
candidate_paths = sorted(glob(os.path.join(DATA_DIR, "*.txt")))
candidate_features = {}
for path in candidate_paths:
    battery_id = os.path.basename(path).replace(".txt", "")
    trimmed = load_trimmed_battery(path)
    feats = extract_features(trimmed)
    candidate_features[battery_id] = feats

# ─── Similarity Evaluation ───────────────────────────────────────
results = []

for query_battery, query_feats in query_features.items():
    for feat_name, feat_val in query_feats.items():
        if pd.isna(feat_val):
            continue

        diffs = []
        for other_battery, other_feats in candidate_features.items():
            if other_battery == query_battery:
                continue
            other_val = other_feats.get(feat_name, np.nan)
            if pd.isna(other_val):
                continue
            diffs.append({
                "similar_battery": other_battery,
                "difference": abs(other_val - feat_val)
            })

        # Sort and keep top-K
        top_k = sorted(diffs, key=lambda x: x["difference"])[:TOP_K]
        for entry in top_k:
            results.append({
                "query_battery": query_battery,
                "feature": feat_name,
                "feature_value": feat_val,
                **entry
            })

# ─── Save Result ─────────────────────────────────────────────────
df = pd.DataFrame(results)
df.to_csv("top1_similar_batteries_typeB.csv", index=False)
print("✅ Saved to top1_similar_batteries_typeB.csv")
# Out:
# ✅ Saved to top1_similar_batteries_typeB.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.table import Table
import matplotlib.colors as mcolors
from ipywidgets import interact, IntSlider
import math

# Load CSV
df = pd.read_csv("top1_similar_batteries_typeB.csv")

# Assign color per query_battery
all_colors = list(mcolors.TABLEAU_COLORS.values()) + list(mcolors.CSS4_COLORS.values())
unique_queries = df['query_battery'].unique()
color_map = {qb: all_colors[i % len(all_colors)] for i, qb in enumerate(unique_queries)}

# ─── Pagination ───────────────────────────────────────────────
ROWS_PER_PAGE = 30
num_pages = math.ceil(len(df) / ROWS_PER_PAGE)

def plot_colored_table_page(page=0):
    start = page * ROWS_PER_PAGE
    end = start + ROWS_PER_PAGE
    df_page = df.iloc[start:end]

    fig, ax = plt.subplots(figsize=(14, min(0.5 * len(df_page) + 1, 20)))
    ax.set_axis_off()

    table = Table(ax, bbox=[0, 0, 1, 1])
    n_rows, n_cols = df_page.shape
    width, height = 1.0 / n_cols, 1.0 / (n_rows + 1)

    # Header row
    for i, col in enumerate(df_page.columns):
        table.add_cell(0, i, width, height, text=col, loc='center', facecolor='lightgrey')

    # Data rows
    for row in range(n_rows):
        row_color = color_map.get(df_page.iloc[row]['query_battery'], 'white')
        for col in range(n_cols):
            table.add_cell(row + 1, col, width, height,
                           text=str(df_page.iat[row, col]), loc='center', facecolor=row_color)

    ax.add_table(table)
    plt.title(f"Top 1 Similar Batteries — Page {page+1}/{num_pages}", fontsize=14)
    plt.tight_layout()
    plt.show()

# Display interactively with slider
interact(plot_colored_table_page, page=IntSlider(0, 0, num_pages - 1, 1))
# Out:
# interactive(children=(IntSlider(value=0, description='page', max=59), Output()), _dom_classes=('widget-interac…
# <function __main__.plot_colored_table_page(page=0)>

# %% [markdown]
# # Now evaluate Feature => every K => Top N

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dotenv import load_dotenv
from neo4j import GraphDatabase
from tqdm import tqdm


# ─── Load ENV ────────────────────────────────────────────────────
load_dotenv()
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))


# ─── Constants ───────────────────────────────────────────────────
K_VALUES = [10, 50, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
TOP_N = list(range(1, 6))  # 1 to 5

# ─── Ground Truth Loading ───────────────────────────────────────
ground_truth_df = pd.read_csv("top3_similar_batteries_typeB.csv")
ground_truth = {}
for _, row in ground_truth_df.iterrows():
    key = (row["query_battery"], row["feature"])
    if key not in ground_truth:
        ground_truth[key] = []
    ground_truth[key].append(row["similar_battery"])
    print("appended", row["similar_battery"], "to", key)
print(ground_truth)
# Out:
# appended b1c5 to ('b3c18', 'total_cycles')
# appended b2c19 to ('b3c18', 'slope_first_10_cycles')
# appended b1c0 to ('b3c18', 'slope_last_10_cycles')
# appended b2c1 to ('b3c18', 'mean_grad_first_10_cycles')
# appended b1c0 to ('b3c18', 'mean_grad_last_10_cycles')
# appended b2c6 to ('b3c18', 'slope_first_50_cycles')
# appended b1c2 to ('b3c18', 'slope_last_50_cycles')
# appended b2c6 to ('b3c18', 'mean_grad_first_50_cycles')
# appended b1c2 to ('b3c18', 'mean_grad_last_50_cycles')
# appended b2c23 to ('b3c18', 'slope_first_100_cycles')
# appended b1c24 to ('b3c18', 'slope_last_100_cycles')
# appended b2c18 to ('b3c18', 'mean_grad_first_100_cycles')
# appended b1c24 to ('b3c18', 'mean_grad_last_100_cycles')
# appended b2c22 to ('b3c18', 'slope_first_200_cycles')
# appended b1c20 to ('b3c18', 'slope_last_200_cycles')
# appended b2c35 to ('b3c18', 'mean_grad_first_200_cycles')
# appended b1c20 to ('b3c18', 'mean_grad_last_200_cycles')
# appended b2c37 to ('b3c18', 'slope_first_300_cycles')
# appended b1c20 to ('b3c18', 'slope_last_300_cycles')
# appended b2c39 to ('b3c18', 'mean_grad_first_300_cycles')
# appended b1c20 to ('b3c18', 'mean_grad_last_300_cycles')
# appended b1c18 to ('b3c18', 'slope_first_400_cycles')
# appended b1c3 to ('b3c18', 'slope_last_400_cycles')
# appended b1c18 to ('b3c18', 'mean_grad_first_400_cycles')
# appended b1c3 to ('b3c18', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c18', 'slope_first_500_cycles')
# appended b1c3 to ('b3c18', 'slope_last_500_cycles')
# appended b1c43 to ('b3c18', 'mean_grad_first_500_cycles')
# appended b1c3 to ('b3c18', 'mean_grad_last_500_cycles')
# appended b1c19 to ('b3c18', 'slope_first_600_cycles')
# appended b1c3 to ('b3c18', 'slope_last_600_cycles')
# appended b1c19 to ('b3c18', 'mean_grad_first_600_cycles')
# appended b1c3 to ('b3c18', 'mean_grad_last_600_cycles')
# appended b1c7 to ('b3c18', 'slope_first_700_cycles')
# appended b1c3 to ('b3c18', 'slope_last_700_cycles')
# appended b1c27 to ('b3c18', 'mean_grad_first_700_cycles')
# appended b1c3 to ('b3c18', 'mean_grad_last_700_cycles')
# appended b1c24 to ('b3c18', 'slope_first_800_cycles')
# appended b1c4 to ('b3c18', 'slope_last_800_cycles')
# appended b1c40 to ('b3c18', 'mean_grad_first_800_cycles')
# appended b1c4 to ('b3c18', 'mean_grad_last_800_cycles')
# appended b1c9 to ('b3c18', 'slope_first_900_cycles')
# appended b1c3 to ('b3c18', 'slope_last_900_cycles')
# appended b1c9 to ('b3c18', 'mean_grad_first_900_cycles')
# appended b1c3 to ('b3c18', 'mean_grad_last_900_cycles')
# appended b1c5 to ('b3c18', 'slope_first_1000_cycles')
# appended b1c4 to ('b3c18', 'slope_last_1000_cycles')
# appended b1c5 to ('b3c18', 'mean_grad_first_1000_cycles')
# appended b1c4 to ('b3c18', 'mean_grad_last_1000_cycles')
# appended b1c27 to ('b3c24', 'total_cycles')
# appended b2c3 to ('b3c24', 'slope_first_10_cycles')
# appended b1c33 to ('b3c24', 'slope_last_10_cycles')
# appended b2c19 to ('b3c24', 'mean_grad_first_10_cycles')
# appended b1c7 to ('b3c24', 'mean_grad_last_10_cycles')
# appended b2c23 to ('b3c24', 'slope_first_50_cycles')
# appended b1c39 to ('b3c24', 'slope_last_50_cycles')
# appended b2c23 to ('b3c24', 'mean_grad_first_50_cycles')
# appended b1c39 to ('b3c24', 'mean_grad_last_50_cycles')
# appended b2c21 to ('b3c24', 'slope_first_100_cycles')
# appended b1c36 to ('b3c24', 'slope_last_100_cycles')
# appended b2c26 to ('b3c24', 'mean_grad_first_100_cycles')
# appended b1c36 to ('b3c24', 'mean_grad_last_100_cycles')
# appended b2c38 to ('b3c24', 'slope_first_200_cycles')
# appended b1c40 to ('b3c24', 'slope_last_200_cycles')
# appended b2c42 to ('b3c24', 'mean_grad_first_200_cycles')
# appended b1c41 to ('b3c24', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c24', 'slope_first_300_cycles')
# appended b1c20 to ('b3c24', 'slope_last_300_cycles')
# appended b2c36 to ('b3c24', 'mean_grad_first_300_cycles')
# appended b1c20 to ('b3c24', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c24', 'slope_first_400_cycles')
# appended b1c3 to ('b3c24', 'slope_last_400_cycles')
# appended b1c18 to ('b3c24', 'mean_grad_first_400_cycles')
# appended b1c3 to ('b3c24', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c24', 'slope_first_500_cycles')
# appended b1c3 to ('b3c24', 'slope_last_500_cycles')
# appended b1c43 to ('b3c24', 'mean_grad_first_500_cycles')
# appended b1c3 to ('b3c24', 'mean_grad_last_500_cycles')
# appended b1c33 to ('b3c24', 'slope_first_600_cycles')
# appended b1c3 to ('b3c24', 'slope_last_600_cycles')
# appended b1c30 to ('b3c24', 'mean_grad_first_600_cycles')
# appended b1c3 to ('b3c24', 'mean_grad_last_600_cycles')
# appended b1c25 to ('b3c24', 'slope_first_700_cycles')
# appended b1c4 to ('b3c24', 'slope_last_700_cycles')
# appended b1c25 to ('b3c24', 'mean_grad_first_700_cycles')
# appended b1c4 to ('b3c24', 'mean_grad_last_700_cycles')
# appended b1c27 to ('b3c24', 'slope_first_800_cycles')
# appended b1c4 to ('b3c24', 'slope_last_800_cycles')
# appended b1c25 to ('b3c24', 'mean_grad_first_800_cycles')
# appended b1c4 to ('b3c24', 'mean_grad_last_800_cycles')
# appended b1c29 to ('b3c44', 'total_cycles')
# appended b2c19 to ('b3c44', 'slope_first_10_cycles')
# appended b1c6 to ('b3c44', 'slope_last_10_cycles')
# appended b2c19 to ('b3c44', 'mean_grad_first_10_cycles')
# appended b1c6 to ('b3c44', 'mean_grad_last_10_cycles')
# appended b2c23 to ('b3c44', 'slope_first_50_cycles')
# appended b2c18 to ('b3c44', 'slope_last_50_cycles')
# appended b2c4 to ('b3c44', 'mean_grad_first_50_cycles')
# appended b2c18 to ('b3c44', 'mean_grad_last_50_cycles')
# appended b2c26 to ('b3c44', 'slope_first_100_cycles')
# appended b1c45 to ('b3c44', 'slope_last_100_cycles')
# appended b2c25 to ('b3c44', 'mean_grad_first_100_cycles')
# appended b1c45 to ('b3c44', 'mean_grad_last_100_cycles')
# appended b1c18 to ('b3c44', 'slope_first_200_cycles')
# appended b1c15 to ('b3c44', 'slope_last_200_cycles')
# appended b2c28 to ('b3c44', 'mean_grad_first_200_cycles')
# appended b1c15 to ('b3c44', 'mean_grad_last_200_cycles')
# appended b1c11 to ('b3c44', 'slope_first_300_cycles')
# appended b1c28 to ('b3c44', 'slope_last_300_cycles')
# appended b1c18 to ('b3c44', 'mean_grad_first_300_cycles')
# appended b1c28 to ('b3c44', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c44', 'slope_first_400_cycles')
# appended b1c15 to ('b3c44', 'slope_last_400_cycles')
# appended b1c11 to ('b3c44', 'mean_grad_first_400_cycles')
# appended b1c15 to ('b3c44', 'mean_grad_last_400_cycles')
# appended b1c42 to ('b3c44', 'slope_first_500_cycles')
# appended b1c15 to ('b3c44', 'slope_last_500_cycles')
# appended b1c11 to ('b3c44', 'mean_grad_first_500_cycles')
# appended b1c15 to ('b3c44', 'mean_grad_last_500_cycles')
# appended b1c25 to ('b3c44', 'slope_first_600_cycles')
# appended b1c41 to ('b3c44', 'slope_last_600_cycles')
# appended b1c34 to ('b3c44', 'mean_grad_first_600_cycles')
# appended b1c41 to ('b3c44', 'mean_grad_last_600_cycles')
# appended b1c7 to ('b3c44', 'slope_first_700_cycles')
# appended b1c5 to ('b3c44', 'slope_last_700_cycles')
# appended b1c7 to ('b3c44', 'mean_grad_first_700_cycles')
# appended b1c5 to ('b3c44', 'mean_grad_last_700_cycles')
# appended b1c40 to ('b3c44', 'slope_first_800_cycles')
# appended b1c5 to ('b3c44', 'slope_last_800_cycles')
# appended b1c40 to ('b3c44', 'mean_grad_first_800_cycles')
# appended b1c5 to ('b3c44', 'mean_grad_last_800_cycles')
# appended b1c40 to ('b3c44', 'slope_first_900_cycles')
# appended b1c5 to ('b3c44', 'slope_last_900_cycles')
# appended b1c29 to ('b3c44', 'mean_grad_first_900_cycles')
# appended b1c5 to ('b3c44', 'mean_grad_last_900_cycles')
# appended b1c31 to ('b3c15', 'total_cycles')
# appended b2c19 to ('b3c15', 'slope_first_10_cycles')
# appended b1c30 to ('b3c15', 'slope_last_10_cycles')
# appended b2c19 to ('b3c15', 'mean_grad_first_10_cycles')
# appended b1c18 to ('b3c15', 'mean_grad_last_10_cycles')
# appended b2c4 to ('b3c15', 'slope_first_50_cycles')
# appended b1c15 to ('b3c15', 'slope_last_50_cycles')
# appended b2c12 to ('b3c15', 'mean_grad_first_50_cycles')
# appended b1c33 to ('b3c15', 'mean_grad_last_50_cycles')
# appended b2c10 to ('b3c15', 'slope_first_100_cycles')
# appended b1c17 to ('b3c15', 'slope_last_100_cycles')
# appended b2c23 to ('b3c15', 'mean_grad_first_100_cycles')
# appended b1c17 to ('b3c15', 'mean_grad_last_100_cycles')
# appended b2c24 to ('b3c15', 'slope_first_200_cycles')
# appended b1c40 to ('b3c15', 'slope_last_200_cycles')
# appended b2c5 to ('b3c15', 'mean_grad_first_200_cycles')
# appended b1c40 to ('b3c15', 'mean_grad_last_200_cycles')
# appended b2c32 to ('b3c15', 'slope_first_300_cycles')
# appended b1c24 to ('b3c15', 'slope_last_300_cycles')
# appended b2c37 to ('b3c15', 'mean_grad_first_300_cycles')
# appended b1c24 to ('b3c15', 'mean_grad_last_300_cycles')
# appended b1c18 to ('b3c15', 'slope_first_400_cycles')
# appended b1c11 to ('b3c15', 'slope_last_400_cycles')
# appended b1c18 to ('b3c15', 'mean_grad_first_400_cycles')
# appended b1c11 to ('b3c15', 'mean_grad_last_400_cycles')
# appended b1c6 to ('b3c15', 'slope_first_500_cycles')
# appended b1c5 to ('b3c15', 'slope_last_500_cycles')
# appended b1c38 to ('b3c15', 'mean_grad_first_500_cycles')
# appended b1c5 to ('b3c15', 'mean_grad_last_500_cycles')
# appended b1c11 to ('b3c15', 'slope_first_600_cycles')
# appended b1c24 to ('b3c15', 'slope_last_600_cycles')
# appended b1c11 to ('b3c15', 'mean_grad_first_600_cycles')
# appended b1c24 to ('b3c15', 'mean_grad_last_600_cycles')
# appended b1c25 to ('b3c15', 'slope_first_700_cycles')
# appended b1c15 to ('b3c15', 'slope_last_700_cycles')
# appended b1c25 to ('b3c15', 'mean_grad_first_700_cycles')
# appended b1c15 to ('b3c15', 'mean_grad_last_700_cycles')
# appended b1c17 to ('b3c15', 'slope_first_800_cycles')
# appended b1c5 to ('b3c15', 'slope_last_800_cycles')
# appended b1c25 to ('b3c15', 'mean_grad_first_800_cycles')
# appended b1c5 to ('b3c15', 'mean_grad_last_800_cycles')
# appended b1c32 to ('b3c31', 'total_cycles')
# appended b2c19 to ('b3c31', 'slope_first_10_cycles')
# appended b2c23 to ('b3c31', 'slope_last_10_cycles')
# appended b2c19 to ('b3c31', 'mean_grad_first_10_cycles')
# appended b2c10 to ('b3c31', 'mean_grad_last_10_cycles')
# appended b2c4 to ('b3c31', 'slope_first_50_cycles')
# appended b2c23 to ('b3c31', 'slope_last_50_cycles')
# appended b2c12 to ('b3c31', 'mean_grad_first_50_cycles')
# appended b2c23 to ('b3c31', 'mean_grad_last_50_cycles')
# appended b2c11 to ('b3c31', 'slope_first_100_cycles')
# appended b1c39 to ('b3c31', 'slope_last_100_cycles')
# appended b2c23 to ('b3c31', 'mean_grad_first_100_cycles')
# appended b1c39 to ('b3c31', 'mean_grad_last_100_cycles')
# appended b2c24 to ('b3c31', 'slope_first_200_cycles')
# appended b1c43 to ('b3c31', 'slope_last_200_cycles')
# appended b2c45 to ('b3c31', 'mean_grad_first_200_cycles')
# appended b1c43 to ('b3c31', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c31', 'slope_first_300_cycles')
# appended b1c7 to ('b3c31', 'slope_last_300_cycles')
# appended b2c32 to ('b3c31', 'mean_grad_first_300_cycles')
# appended b1c27 to ('b3c31', 'mean_grad_last_300_cycles')
# appended b1c18 to ('b3c31', 'slope_first_400_cycles')
# appended b1c28 to ('b3c31', 'slope_last_400_cycles')
# appended b1c18 to ('b3c31', 'mean_grad_first_400_cycles')
# appended b1c28 to ('b3c31', 'mean_grad_last_400_cycles')
# appended b1c6 to ('b3c31', 'slope_first_500_cycles')
# appended b1c29 to ('b3c31', 'slope_last_500_cycles')
# appended b1c18 to ('b3c31', 'mean_grad_first_500_cycles')
# appended b1c9 to ('b3c31', 'mean_grad_last_500_cycles')
# appended b1c15 to ('b3c31', 'slope_first_600_cycles')
# appended b1c14 to ('b3c31', 'slope_last_600_cycles')
# appended b1c36 to ('b3c31', 'mean_grad_first_600_cycles')
# appended b1c14 to ('b3c31', 'mean_grad_last_600_cycles')
# appended b1c32 to ('b3c31', 'slope_first_700_cycles')
# appended b1c17 to ('b3c31', 'slope_last_700_cycles')
# appended b1c15 to ('b3c31', 'mean_grad_first_700_cycles')
# appended b1c41 to ('b3c31', 'mean_grad_last_700_cycles')
# appended b1c23 to ('b3c25', 'total_cycles')
# appended b2c19 to ('b3c25', 'slope_first_10_cycles')
# appended b1c5 to ('b3c25', 'slope_last_10_cycles')
# appended b2c19 to ('b3c25', 'mean_grad_first_10_cycles')
# appended b1c43 to ('b3c25', 'mean_grad_last_10_cycles')
# appended b2c23 to ('b3c25', 'slope_first_50_cycles')
# appended b1c35 to ('b3c25', 'slope_last_50_cycles')
# appended b2c13 to ('b3c25', 'mean_grad_first_50_cycles')
# appended b1c16 to ('b3c25', 'mean_grad_last_50_cycles')
# appended b2c26 to ('b3c25', 'slope_first_100_cycles')
# appended b1c31 to ('b3c25', 'slope_last_100_cycles')
# appended b2c25 to ('b3c25', 'mean_grad_first_100_cycles')
# appended b1c31 to ('b3c25', 'mean_grad_last_100_cycles')
# appended b2c38 to ('b3c25', 'slope_first_200_cycles')
# appended b1c25 to ('b3c25', 'slope_last_200_cycles')
# appended b2c42 to ('b3c25', 'mean_grad_first_200_cycles')
# appended b1c25 to ('b3c25', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c25', 'slope_first_300_cycles')
# appended b1c18 to ('b3c25', 'slope_last_300_cycles')
# appended b1c18 to ('b3c25', 'mean_grad_first_300_cycles')
# appended b1c18 to ('b3c25', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c25', 'slope_first_400_cycles')
# appended b1c18 to ('b3c25', 'slope_last_400_cycles')
# appended b1c11 to ('b3c25', 'mean_grad_first_400_cycles')
# appended b1c18 to ('b3c25', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c25', 'slope_first_500_cycles')
# appended b1c3 to ('b3c25', 'slope_last_500_cycles')
# appended b1c6 to ('b3c25', 'mean_grad_first_500_cycles')
# appended b1c3 to ('b3c25', 'mean_grad_last_500_cycles')
# appended b1c19 to ('b3c25', 'slope_first_600_cycles')
# appended b1c3 to ('b3c25', 'slope_last_600_cycles')
# appended b1c19 to ('b3c25', 'mean_grad_first_600_cycles')
# appended b1c3 to ('b3c25', 'mean_grad_last_600_cycles')
# appended b1c29 to ('b3c25', 'slope_first_700_cycles')
# appended b1c3 to ('b3c25', 'slope_last_700_cycles')
# appended b1c14 to ('b3c25', 'mean_grad_first_700_cycles')
# appended b1c3 to ('b3c25', 'mean_grad_last_700_cycles')
# appended b1c24 to ('b3c25', 'slope_first_800_cycles')
# appended b1c3 to ('b3c25', 'slope_last_800_cycles')
# appended b1c40 to ('b3c25', 'mean_grad_first_800_cycles')
# appended b1c3 to ('b3c25', 'mean_grad_last_800_cycles')
# appended b1c24 to ('b3c25', 'slope_first_900_cycles')
# appended b1c3 to ('b3c25', 'slope_last_900_cycles')
# appended b1c24 to ('b3c25', 'mean_grad_first_900_cycles')
# appended b1c3 to ('b3c25', 'mean_grad_last_900_cycles')
# appended b1c41 to ('b3c43', 'total_cycles')
# appended b2c19 to ('b3c43', 'slope_first_10_cycles')
# appended b1c25 to ('b3c43', 'slope_last_10_cycles')
# appended b2c19 to ('b3c43', 'mean_grad_first_10_cycles')
# appended b1c30 to ('b3c43', 'mean_grad_last_10_cycles')
# appended b2c13 to ('b3c43', 'slope_first_50_cycles')
# appended b1c15 to ('b3c43', 'slope_last_50_cycles')
# appended b2c12 to ('b3c43', 'mean_grad_first_50_cycles')
# appended b1c33 to ('b3c43', 'mean_grad_last_50_cycles')
# appended b2c25 to ('b3c43', 'slope_first_100_cycles')
# appended b1c31 to ('b3c43', 'slope_last_100_cycles')
# appended b2c10 to ('b3c43', 'mean_grad_first_100_cycles')
# appended b1c27 to ('b3c43', 'mean_grad_last_100_cycles')
# appended b2c43 to ('b3c43', 'slope_first_200_cycles')
# appended b1c21 to ('b3c43', 'slope_last_200_cycles')
# appended b2c42 to ('b3c43', 'mean_grad_first_200_cycles')
# appended b1c14 to ('b3c43', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c43', 'slope_first_300_cycles')
# appended b1c11 to ('b3c43', 'slope_last_300_cycles')
# appended b1c18 to ('b3c43', 'mean_grad_first_300_cycles')
# appended b1c11 to ('b3c43', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c43', 'slope_first_400_cycles')
# appended b1c24 to ('b3c43', 'slope_last_400_cycles')
# appended b1c11 to ('b3c43', 'mean_grad_first_400_cycles')
# appended b1c24 to ('b3c43', 'mean_grad_last_400_cycles')
# appended b1c35 to ('b3c43', 'slope_first_500_cycles')
# appended b1c5 to ('b3c43', 'slope_last_500_cycles')
# appended b1c11 to ('b3c43', 'mean_grad_first_500_cycles')
# appended b1c5 to ('b3c43', 'mean_grad_last_500_cycles')
# appended b1c25 to ('b3c43', 'slope_first_600_cycles')
# appended b1c24 to ('b3c43', 'slope_last_600_cycles')
# appended b1c34 to ('b3c43', 'mean_grad_first_600_cycles')
# appended b1c24 to ('b3c43', 'mean_grad_last_600_cycles')
# appended b1c29 to ('b3c43', 'slope_first_700_cycles')
# appended b1c15 to ('b3c43', 'slope_last_700_cycles')
# appended b1c17 to ('b3c43', 'mean_grad_first_700_cycles')
# appended b1c15 to ('b3c43', 'mean_grad_last_700_cycles')
# appended b1c24 to ('b3c43', 'slope_first_800_cycles')
# appended b1c3 to ('b3c43', 'slope_last_800_cycles')
# appended b1c24 to ('b3c43', 'mean_grad_first_800_cycles')
# appended b1c3 to ('b3c43', 'mean_grad_last_800_cycles')
# appended b1c41 to ('b3c43', 'slope_first_900_cycles')
# appended b1c3 to ('b3c43', 'slope_last_900_cycles')
# appended b1c23 to ('b3c43', 'mean_grad_first_900_cycles')
# appended b1c3 to ('b3c43', 'mean_grad_last_900_cycles')
# appended b1c41 to ('b3c43', 'slope_first_1000_cycles')
# appended b1c3 to ('b3c43', 'slope_last_1000_cycles')
# appended b1c23 to ('b3c43', 'mean_grad_first_1000_cycles')
# appended b1c3 to ('b3c43', 'mean_grad_last_1000_cycles')
# appended b1c23 to ('b3c0', 'total_cycles')
# appended b2c19 to ('b3c0', 'slope_first_10_cycles')
# appended b1c18 to ('b3c0', 'slope_last_10_cycles')
# appended b2c19 to ('b3c0', 'mean_grad_first_10_cycles')
# appended b1c18 to ('b3c0', 'mean_grad_last_10_cycles')
# appended b2c18 to ('b3c0', 'slope_first_50_cycles')
# appended b1c37 to ('b3c0', 'slope_last_50_cycles')
# appended b2c4 to ('b3c0', 'mean_grad_first_50_cycles')
# appended b1c37 to ('b3c0', 'mean_grad_last_50_cycles')
# appended b2c11 to ('b3c0', 'slope_first_100_cycles')
# appended b1c36 to ('b3c0', 'slope_last_100_cycles')
# appended b2c10 to ('b3c0', 'mean_grad_first_100_cycles')
# appended b1c36 to ('b3c0', 'mean_grad_last_100_cycles')
# appended b2c42 to ('b3c0', 'slope_first_200_cycles')
# appended b1c11 to ('b3c0', 'slope_last_200_cycles')
# appended b2c24 to ('b3c0', 'mean_grad_first_200_cycles')
# appended b1c11 to ('b3c0', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c0', 'slope_first_300_cycles')
# appended b1c5 to ('b3c0', 'slope_last_300_cycles')
# appended b2c33 to ('b3c0', 'mean_grad_first_300_cycles')
# appended b1c5 to ('b3c0', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c0', 'slope_first_400_cycles')
# appended b1c5 to ('b3c0', 'slope_last_400_cycles')
# appended b1c18 to ('b3c0', 'mean_grad_first_400_cycles')
# appended b1c5 to ('b3c0', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c0', 'slope_first_500_cycles')
# appended b1c11 to ('b3c0', 'slope_last_500_cycles')
# appended b1c37 to ('b3c0', 'mean_grad_first_500_cycles')
# appended b1c11 to ('b3c0', 'mean_grad_last_500_cycles')
# appended b1c19 to ('b3c0', 'slope_first_600_cycles')
# appended b1c11 to ('b3c0', 'slope_last_600_cycles')
# appended b1c19 to ('b3c0', 'mean_grad_first_600_cycles')
# appended b1c11 to ('b3c0', 'mean_grad_last_600_cycles')
# appended b1c7 to ('b3c0', 'slope_first_700_cycles')
# appended b1c11 to ('b3c0', 'slope_last_700_cycles')
# appended b1c7 to ('b3c0', 'mean_grad_first_700_cycles')
# appended b1c11 to ('b3c0', 'mean_grad_last_700_cycles')
# appended b1c24 to ('b3c0', 'slope_first_800_cycles')
# appended b1c3 to ('b3c0', 'slope_last_800_cycles')
# appended b1c40 to ('b3c0', 'mean_grad_first_800_cycles')
# appended b1c3 to ('b3c0', 'mean_grad_last_800_cycles')
# appended b1c23 to ('b3c0', 'slope_first_900_cycles')
# appended b1c3 to ('b3c0', 'slope_last_900_cycles')
# appended b1c24 to ('b3c0', 'mean_grad_first_900_cycles')
# appended b1c3 to ('b3c0', 'mean_grad_last_900_cycles')
# appended b1c23 to ('b3c0', 'slope_first_1000_cycles')
# appended b1c3 to ('b3c0', 'slope_last_1000_cycles')
# appended b1c24 to ('b3c0', 'mean_grad_first_1000_cycles')
# appended b1c3 to ('b3c0', 'mean_grad_last_1000_cycles')
# appended b1c25 to ('b3c27', 'total_cycles')
# appended b2c3 to ('b3c27', 'slope_first_10_cycles')
# appended b1c36 to ('b3c27', 'slope_last_10_cycles')
# appended b2c19 to ('b3c27', 'mean_grad_first_10_cycles')
# appended b1c15 to ('b3c27', 'mean_grad_last_10_cycles')
# appended b2c23 to ('b3c27', 'slope_first_50_cycles')
# appended b1c44 to ('b3c27', 'slope_last_50_cycles')
# appended b2c4 to ('b3c27', 'mean_grad_first_50_cycles')
# appended b1c27 to ('b3c27', 'mean_grad_last_50_cycles')
# appended b2c25 to ('b3c27', 'slope_first_100_cycles')
# appended b1c27 to ('b3c27', 'slope_last_100_cycles')
# appended b2c11 to ('b3c27', 'mean_grad_first_100_cycles')
# appended b1c27 to ('b3c27', 'mean_grad_last_100_cycles')
# appended b2c41 to ('b3c27', 'slope_first_200_cycles')
# appended b1c25 to ('b3c27', 'slope_last_200_cycles')
# appended b2c30 to ('b3c27', 'mean_grad_first_200_cycles')
# appended b1c29 to ('b3c27', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c27', 'slope_first_300_cycles')
# appended b1c41 to ('b3c27', 'slope_last_300_cycles')
# appended b2c34 to ('b3c27', 'mean_grad_first_300_cycles')
# appended b1c41 to ('b3c27', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c27', 'slope_first_400_cycles')
# appended b1c5 to ('b3c27', 'slope_last_400_cycles')
# appended b1c18 to ('b3c27', 'mean_grad_first_400_cycles')
# appended b1c5 to ('b3c27', 'mean_grad_last_400_cycles')
# appended b1c6 to ('b3c27', 'slope_first_500_cycles')
# appended b1c11 to ('b3c27', 'slope_last_500_cycles')
# appended b1c43 to ('b3c27', 'mean_grad_first_500_cycles')
# appended b1c11 to ('b3c27', 'mean_grad_last_500_cycles')
# appended b1c11 to ('b3c27', 'slope_first_600_cycles')
# appended b1c11 to ('b3c27', 'slope_last_600_cycles')
# appended b1c30 to ('b3c27', 'mean_grad_first_600_cycles')
# appended b1c11 to ('b3c27', 'mean_grad_last_600_cycles')
# appended b1c25 to ('b3c27', 'slope_first_700_cycles')
# appended b1c11 to ('b3c27', 'slope_last_700_cycles')
# appended b1c25 to ('b3c27', 'mean_grad_first_700_cycles')
# appended b1c11 to ('b3c27', 'mean_grad_last_700_cycles')
# appended b1c27 to ('b3c27', 'slope_first_800_cycles')
# appended b1c3 to ('b3c27', 'slope_last_800_cycles')
# appended b1c25 to ('b3c27', 'mean_grad_first_800_cycles')
# appended b1c3 to ('b3c27', 'mean_grad_last_800_cycles')
# appended b1c43 to ('b3c6', 'total_cycles')
# appended b2c1 to ('b3c6', 'slope_first_10_cycles')
# appended b1c2 to ('b3c6', 'slope_last_10_cycles')
# appended b2c1 to ('b3c6', 'mean_grad_first_10_cycles')
# appended b1c0 to ('b3c6', 'mean_grad_last_10_cycles')
# appended b2c0 to ('b3c6', 'slope_first_50_cycles')
# appended b1c2 to ('b3c6', 'slope_last_50_cycles')
# appended b2c0 to ('b3c6', 'mean_grad_first_50_cycles')
# appended b1c2 to ('b3c6', 'mean_grad_last_50_cycles')
# appended b2c3 to ('b3c6', 'slope_first_100_cycles')
# appended b1c2 to ('b3c6', 'slope_last_100_cycles')
# appended b2c3 to ('b3c6', 'mean_grad_first_100_cycles')
# appended b1c2 to ('b3c6', 'mean_grad_last_100_cycles')
# appended b2c12 to ('b3c6', 'slope_first_200_cycles')
# appended b1c3 to ('b3c6', 'slope_last_200_cycles')
# appended b2c12 to ('b3c6', 'mean_grad_first_200_cycles')
# appended b1c3 to ('b3c6', 'mean_grad_last_200_cycles')
# appended b2c4 to ('b3c6', 'slope_first_300_cycles')
# appended b1c4 to ('b3c6', 'slope_last_300_cycles')
# appended b2c4 to ('b3c6', 'mean_grad_first_300_cycles')
# appended b1c4 to ('b3c6', 'mean_grad_last_300_cycles')
# appended b2c21 to ('b3c6', 'slope_first_400_cycles')
# appended b1c4 to ('b3c6', 'slope_last_400_cycles')
# appended b2c21 to ('b3c6', 'mean_grad_first_400_cycles')
# appended b1c4 to ('b3c6', 'mean_grad_last_400_cycles')
# appended b2c10 to ('b3c6', 'slope_first_500_cycles')
# appended b1c4 to ('b3c6', 'slope_last_500_cycles')
# appended b2c10 to ('b3c6', 'mean_grad_first_500_cycles')
# appended b1c4 to ('b3c6', 'mean_grad_last_500_cycles')
# appended b1c38 to ('b3c6', 'slope_first_600_cycles')
# appended b1c3 to ('b3c6', 'slope_last_600_cycles')
# appended b1c39 to ('b3c6', 'mean_grad_first_600_cycles')
# appended b1c3 to ('b3c6', 'mean_grad_last_600_cycles')
# appended b1c27 to ('b3c11', 'total_cycles')
# appended b2c19 to ('b3c11', 'slope_first_10_cycles')
# appended b1c30 to ('b3c11', 'slope_last_10_cycles')
# appended b2c19 to ('b3c11', 'mean_grad_first_10_cycles')
# appended b1c18 to ('b3c11', 'mean_grad_last_10_cycles')
# appended b2c12 to ('b3c11', 'slope_first_50_cycles')
# appended b1c16 to ('b3c11', 'slope_last_50_cycles')
# appended b2c6 to ('b3c11', 'mean_grad_first_50_cycles')
# appended b1c31 to ('b3c11', 'mean_grad_last_50_cycles')
# appended b2c23 to ('b3c11', 'slope_first_100_cycles')
# appended b1c31 to ('b3c11', 'slope_last_100_cycles')
# appended b2c23 to ('b3c11', 'mean_grad_first_100_cycles')
# appended b1c27 to ('b3c11', 'mean_grad_last_100_cycles')
# appended b2c5 to ('b3c11', 'slope_first_200_cycles')
# appended b1c18 to ('b3c11', 'slope_last_200_cycles')
# appended b2c17 to ('b3c11', 'mean_grad_first_200_cycles')
# appended b1c18 to ('b3c11', 'mean_grad_last_200_cycles')
# appended b1c18 to ('b3c11', 'slope_first_300_cycles')
# appended b1c5 to ('b3c11', 'slope_last_300_cycles')
# appended b2c39 to ('b3c11', 'mean_grad_first_300_cycles')
# appended b1c5 to ('b3c11', 'mean_grad_last_300_cycles')
# appended b1c18 to ('b3c11', 'slope_first_400_cycles')
# appended b1c24 to ('b3c11', 'slope_last_400_cycles')
# appended b1c18 to ('b3c11', 'mean_grad_first_400_cycles')
# appended b1c24 to ('b3c11', 'mean_grad_last_400_cycles')
# appended b1c39 to ('b3c11', 'slope_first_500_cycles')
# appended b1c24 to ('b3c11', 'slope_last_500_cycles')
# appended b1c39 to ('b3c11', 'mean_grad_first_500_cycles')
# appended b1c24 to ('b3c11', 'mean_grad_last_500_cycles')
# appended b1c32 to ('b3c11', 'slope_first_600_cycles')
# appended b1c24 to ('b3c11', 'slope_last_600_cycles')
# appended b1c15 to ('b3c11', 'mean_grad_first_600_cycles')
# appended b1c24 to ('b3c11', 'mean_grad_last_600_cycles')
# appended b1c19 to ('b3c11', 'slope_first_700_cycles')
# appended b1c24 to ('b3c11', 'slope_last_700_cycles')
# appended b1c11 to ('b3c11', 'mean_grad_first_700_cycles')
# appended b1c24 to ('b3c11', 'mean_grad_last_700_cycles')
# appended b1c27 to ('b3c11', 'slope_first_800_cycles')
# appended b1c5 to ('b3c11', 'slope_last_800_cycles')
# appended b1c25 to ('b3c11', 'mean_grad_first_800_cycles')
# appended b1c5 to ('b3c11', 'mean_grad_last_800_cycles')
# appended b1c5 to ('b3c35', 'total_cycles')
# appended b2c19 to ('b3c35', 'slope_first_10_cycles')
# appended b1c2 to ('b3c35', 'slope_last_10_cycles')
# appended b2c1 to ('b3c35', 'mean_grad_first_10_cycles')
# appended b1c0 to ('b3c35', 'mean_grad_last_10_cycles')
# appended b2c12 to ('b3c35', 'slope_first_50_cycles')
# appended b1c41 to ('b3c35', 'slope_last_50_cycles')
# appended b2c6 to ('b3c35', 'mean_grad_first_50_cycles')
# appended b1c41 to ('b3c35', 'mean_grad_last_50_cycles')
# appended b2c23 to ('b3c35', 'slope_first_100_cycles')
# appended b1c24 to ('b3c35', 'slope_last_100_cycles')
# appended b2c23 to ('b3c35', 'mean_grad_first_100_cycles')
# appended b1c24 to ('b3c35', 'mean_grad_last_100_cycles')
# appended b2c30 to ('b3c35', 'slope_first_200_cycles')
# appended b1c20 to ('b3c35', 'slope_last_200_cycles')
# appended b1c20 to ('b3c35', 'mean_grad_first_200_cycles')
# appended b1c20 to ('b3c35', 'mean_grad_last_200_cycles')
# appended b2c34 to ('b3c35', 'slope_first_300_cycles')
# appended b1c20 to ('b3c35', 'slope_last_300_cycles')
# appended b2c37 to ('b3c35', 'mean_grad_first_300_cycles')
# appended b1c20 to ('b3c35', 'mean_grad_last_300_cycles')
# appended b1c18 to ('b3c35', 'slope_first_400_cycles')
# appended b1c3 to ('b3c35', 'slope_last_400_cycles')
# appended b1c18 to ('b3c35', 'mean_grad_first_400_cycles')
# appended b1c3 to ('b3c35', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c35', 'slope_first_500_cycles')
# appended b1c3 to ('b3c35', 'slope_last_500_cycles')
# appended b1c43 to ('b3c35', 'mean_grad_first_500_cycles')
# appended b1c3 to ('b3c35', 'mean_grad_last_500_cycles')
# appended b1c19 to ('b3c35', 'slope_first_600_cycles')
# appended b1c3 to ('b3c35', 'slope_last_600_cycles')
# appended b1c19 to ('b3c35', 'mean_grad_first_600_cycles')
# appended b1c3 to ('b3c35', 'mean_grad_last_600_cycles')
# appended b1c7 to ('b3c35', 'slope_first_700_cycles')
# appended b1c4 to ('b3c35', 'slope_last_700_cycles')
# appended b1c27 to ('b3c35', 'mean_grad_first_700_cycles')
# appended b1c4 to ('b3c35', 'mean_grad_last_700_cycles')
# appended b1c40 to ('b3c35', 'slope_first_800_cycles')
# appended b1c4 to ('b3c35', 'slope_last_800_cycles')
# appended b1c40 to ('b3c35', 'mean_grad_first_800_cycles')
# appended b1c4 to ('b3c35', 'mean_grad_last_800_cycles')
# appended b1c41 to ('b3c35', 'slope_first_900_cycles')
# appended b1c4 to ('b3c35', 'slope_last_900_cycles')
# appended b1c24 to ('b3c35', 'mean_grad_first_900_cycles')
# appended b1c4 to ('b3c35', 'mean_grad_last_900_cycles')
# appended b1c9 to ('b3c35', 'slope_first_1000_cycles')
# appended b1c4 to ('b3c35', 'slope_last_1000_cycles')
# appended b1c9 to ('b3c35', 'mean_grad_first_1000_cycles')
# appended b1c4 to ('b3c35', 'mean_grad_last_1000_cycles')
# appended b1c11 to ('b3c40', 'total_cycles')
# appended b2c0 to ('b3c40', 'slope_first_10_cycles')
# appended b1c43 to ('b3c40', 'slope_last_10_cycles')
# appended b2c3 to ('b3c40', 'mean_grad_first_10_cycles')
# appended b1c27 to ('b3c40', 'mean_grad_last_10_cycles')
# appended b2c23 to ('b3c40', 'slope_first_50_cycles')
# appended b1c43 to ('b3c40', 'slope_last_50_cycles')
# appended b2c13 to ('b3c40', 'mean_grad_first_50_cycles')
# appended b1c43 to ('b3c40', 'mean_grad_last_50_cycles')
# appended b2c25 to ('b3c40', 'slope_first_100_cycles')
# appended b1c5 to ('b3c40', 'slope_last_100_cycles')
# appended b2c11 to ('b3c40', 'mean_grad_first_100_cycles')
# appended b1c5 to ('b3c40', 'mean_grad_last_100_cycles')
# appended b2c41 to ('b3c40', 'slope_first_200_cycles')
# appended b1c23 to ('b3c40', 'slope_last_200_cycles')
# appended b2c24 to ('b3c40', 'mean_grad_first_200_cycles')
# appended b1c23 to ('b3c40', 'mean_grad_last_200_cycles')
# appended b2c34 to ('b3c40', 'slope_first_300_cycles')
# appended b1c24 to ('b3c40', 'slope_last_300_cycles')
# appended b2c32 to ('b3c40', 'mean_grad_first_300_cycles')
# appended b1c24 to ('b3c40', 'mean_grad_last_300_cycles')
# appended b1c18 to ('b3c40', 'slope_first_400_cycles')
# appended b1c5 to ('b3c40', 'slope_last_400_cycles')
# appended b1c18 to ('b3c40', 'mean_grad_first_400_cycles')
# appended b1c5 to ('b3c40', 'mean_grad_last_400_cycles')
# appended b1c6 to ('b3c40', 'slope_first_500_cycles')
# appended b1c11 to ('b3c40', 'slope_last_500_cycles')
# appended b1c18 to ('b3c40', 'mean_grad_first_500_cycles')
# appended b1c11 to ('b3c40', 'mean_grad_last_500_cycles')
# appended b1c32 to ('b3c40', 'slope_first_600_cycles')
# appended b1c11 to ('b3c40', 'slope_last_600_cycles')
# appended b1c15 to ('b3c40', 'mean_grad_first_600_cycles')
# appended b1c11 to ('b3c40', 'mean_grad_last_600_cycles')
# appended b1c19 to ('b3c40', 'slope_first_700_cycles')
# appended b1c11 to ('b3c40', 'slope_last_700_cycles')
# appended b1c11 to ('b3c40', 'mean_grad_first_700_cycles')
# appended b1c11 to ('b3c40', 'mean_grad_last_700_cycles')
# appended b1c29 to ('b3c30', 'total_cycles')
# appended b2c3 to ('b3c30', 'slope_first_10_cycles')
# appended b1c33 to ('b3c30', 'slope_last_10_cycles')
# appended b2c19 to ('b3c30', 'mean_grad_first_10_cycles')
# appended b1c19 to ('b3c30', 'mean_grad_last_10_cycles')
# appended b2c18 to ('b3c30', 'slope_first_50_cycles')
# appended b1c38 to ('b3c30', 'slope_last_50_cycles')
# appended b2c4 to ('b3c30', 'mean_grad_first_50_cycles')
# appended b1c38 to ('b3c30', 'mean_grad_last_50_cycles')
# appended b2c25 to ('b3c30', 'slope_first_100_cycles')
# appended b2c6 to ('b3c30', 'slope_last_100_cycles')
# appended b2c11 to ('b3c30', 'mean_grad_first_100_cycles')
# appended b2c6 to ('b3c30', 'mean_grad_last_100_cycles')
# appended b2c42 to ('b3c30', 'slope_first_200_cycles')
# appended b1c21 to ('b3c30', 'slope_last_200_cycles')
# appended b2c41 to ('b3c30', 'mean_grad_first_200_cycles')
# appended b1c21 to ('b3c30', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c30', 'slope_first_300_cycles')
# appended b1c29 to ('b3c30', 'slope_last_300_cycles')
# appended b2c33 to ('b3c30', 'mean_grad_first_300_cycles')
# appended b1c29 to ('b3c30', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c30', 'slope_first_400_cycles')
# appended b1c20 to ('b3c30', 'slope_last_400_cycles')
# appended b1c11 to ('b3c30', 'mean_grad_first_400_cycles')
# appended b1c20 to ('b3c30', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c30', 'slope_first_500_cycles')
# appended b1c41 to ('b3c30', 'slope_last_500_cycles')
# appended b1c6 to ('b3c30', 'mean_grad_first_500_cycles')
# appended b1c41 to ('b3c30', 'mean_grad_last_500_cycles')
# appended b1c19 to ('b3c30', 'slope_first_600_cycles')
# appended b1c24 to ('b3c30', 'slope_last_600_cycles')
# appended b1c19 to ('b3c30', 'mean_grad_first_600_cycles')
# appended b1c24 to ('b3c30', 'mean_grad_last_600_cycles')
# appended b1c26 to ('b3c30', 'slope_first_700_cycles')
# appended b1c15 to ('b3c30', 'slope_last_700_cycles')
# appended b1c27 to ('b3c30', 'mean_grad_first_700_cycles')
# appended b1c15 to ('b3c30', 'mean_grad_last_700_cycles')
# appended b1c40 to ('b3c30', 'slope_first_800_cycles')
# appended b1c5 to ('b3c30', 'slope_last_800_cycles')
# appended b1c29 to ('b3c30', 'mean_grad_first_800_cycles')
# appended b1c5 to ('b3c30', 'mean_grad_last_800_cycles')
# appended b1c29 to ('b3c30', 'slope_first_900_cycles')
# appended b1c5 to ('b3c30', 'slope_last_900_cycles')
# appended b1c29 to ('b3c30', 'mean_grad_first_900_cycles')
# appended b1c5 to ('b3c30', 'mean_grad_last_900_cycles')
# appended b1c17 to ('b3c14', 'total_cycles')
# appended b2c3 to ('b3c14', 'slope_first_10_cycles')
# appended b1c44 to ('b3c14', 'slope_last_10_cycles')
# appended b2c19 to ('b3c14', 'mean_grad_first_10_cycles')
# appended b1c33 to ('b3c14', 'mean_grad_last_10_cycles')
# appended b2c11 to ('b3c14', 'slope_first_50_cycles')
# appended b1c30 to ('b3c14', 'slope_last_50_cycles')
# appended b2c23 to ('b3c14', 'mean_grad_first_50_cycles')
# appended b1c38 to ('b3c14', 'mean_grad_last_50_cycles')
# appended b2c21 to ('b3c14', 'slope_first_100_cycles')
# appended b1c35 to ('b3c14', 'slope_last_100_cycles')
# appended b2c25 to ('b3c14', 'mean_grad_first_100_cycles')
# appended b1c44 to ('b3c14', 'mean_grad_last_100_cycles')
# appended b1c18 to ('b3c14', 'slope_first_200_cycles')
# appended b1c17 to ('b3c14', 'slope_last_200_cycles')
# appended b2c28 to ('b3c14', 'mean_grad_first_200_cycles')
# appended b1c21 to ('b3c14', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c14', 'slope_first_300_cycles')
# appended b1c28 to ('b3c14', 'slope_last_300_cycles')
# appended b1c18 to ('b3c14', 'mean_grad_first_300_cycles')
# appended b1c28 to ('b3c14', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c14', 'slope_first_400_cycles')
# appended b1c17 to ('b3c14', 'slope_last_400_cycles')
# appended b1c18 to ('b3c14', 'mean_grad_first_400_cycles')
# appended b1c40 to ('b3c14', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c14', 'slope_first_500_cycles')
# appended b1c25 to ('b3c14', 'slope_last_500_cycles')
# appended b1c37 to ('b3c14', 'mean_grad_first_500_cycles')
# appended b1c17 to ('b3c14', 'mean_grad_last_500_cycles')
# appended b1c11 to ('b3c14', 'slope_first_600_cycles')
# appended b1c29 to ('b3c14', 'slope_last_600_cycles')
# appended b1c32 to ('b3c14', 'mean_grad_first_600_cycles')
# appended b1c29 to ('b3c14', 'mean_grad_last_600_cycles')
# appended b1c25 to ('b3c14', 'slope_first_700_cycles')
# appended b1c14 to ('b3c14', 'slope_last_700_cycles')
# appended b1c25 to ('b3c14', 'mean_grad_first_700_cycles')
# appended b1c14 to ('b3c14', 'mean_grad_last_700_cycles')
# appended b1c25 to ('b3c14', 'slope_first_800_cycles')
# appended b1c14 to ('b3c14', 'slope_last_800_cycles')
# appended b1c25 to ('b3c14', 'mean_grad_first_800_cycles')
# appended b1c14 to ('b3c14', 'mean_grad_last_800_cycles')
# appended b1c11 to ('b3c20', 'total_cycles')
# appended b2c19 to ('b3c20', 'slope_first_10_cycles')
# appended b1c37 to ('b3c20', 'slope_last_10_cycles')
# appended b2c19 to ('b3c20', 'mean_grad_first_10_cycles')
# appended b1c37 to ('b3c20', 'mean_grad_last_10_cycles')
# appended b2c13 to ('b3c20', 'slope_first_50_cycles')
# appended b2c6 to ('b3c20', 'slope_last_50_cycles')
# appended b2c12 to ('b3c20', 'mean_grad_first_50_cycles')
# appended b1c39 to ('b3c20', 'mean_grad_last_50_cycles')
# appended b2c11 to ('b3c20', 'slope_first_100_cycles')
# appended b1c45 to ('b3c20', 'slope_last_100_cycles')
# appended b2c10 to ('b3c20', 'mean_grad_first_100_cycles')
# appended b1c30 to ('b3c20', 'mean_grad_last_100_cycles')
# appended b2c41 to ('b3c20', 'slope_first_200_cycles')
# appended b1c7 to ('b3c20', 'slope_last_200_cycles')
# appended b2c24 to ('b3c20', 'mean_grad_first_200_cycles')
# appended b1c19 to ('b3c20', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c20', 'slope_first_300_cycles')
# appended b1c29 to ('b3c20', 'slope_last_300_cycles')
# appended b2c34 to ('b3c20', 'mean_grad_first_300_cycles')
# appended b1c29 to ('b3c20', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c20', 'slope_first_400_cycles')
# appended b1c20 to ('b3c20', 'slope_last_400_cycles')
# appended b1c18 to ('b3c20', 'mean_grad_first_400_cycles')
# appended b1c20 to ('b3c20', 'mean_grad_last_400_cycles')
# appended b1c6 to ('b3c20', 'slope_first_500_cycles')
# appended b1c41 to ('b3c20', 'slope_last_500_cycles')
# appended b1c43 to ('b3c20', 'mean_grad_first_500_cycles')
# appended b1c41 to ('b3c20', 'mean_grad_last_500_cycles')
# appended b1c11 to ('b3c20', 'slope_first_600_cycles')
# appended b1c24 to ('b3c20', 'slope_last_600_cycles')
# appended b1c30 to ('b3c20', 'mean_grad_first_600_cycles')
# appended b1c24 to ('b3c20', 'mean_grad_last_600_cycles')
# appended b1c25 to ('b3c20', 'slope_first_700_cycles')
# appended b1c15 to ('b3c20', 'slope_last_700_cycles')
# appended b1c25 to ('b3c20', 'mean_grad_first_700_cycles')
# appended b1c15 to ('b3c20', 'mean_grad_last_700_cycles')
# appended b1c27 to ('b3c20', 'slope_first_800_cycles')
# appended b1c3 to ('b3c20', 'slope_last_800_cycles')
# appended b1c25 to ('b3c20', 'mean_grad_first_800_cycles')
# appended b1c3 to ('b3c20', 'mean_grad_last_800_cycles')
# appended b1c0 to ('b3c7', 'total_cycles')
# appended b2c19 to ('b3c7', 'slope_first_10_cycles')
# appended b1c1 to ('b3c7', 'slope_last_10_cycles')
# appended b2c19 to ('b3c7', 'mean_grad_first_10_cycles')
# appended b1c1 to ('b3c7', 'mean_grad_last_10_cycles')
# appended b2c13 to ('b3c7', 'slope_first_50_cycles')
# appended b1c3 to ('b3c7', 'slope_last_50_cycles')
# appended b2c12 to ('b3c7', 'mean_grad_first_50_cycles')
# appended b1c3 to ('b3c7', 'mean_grad_last_50_cycles')
# appended b2c10 to ('b3c7', 'slope_first_100_cycles')
# appended b1c3 to ('b3c7', 'slope_last_100_cycles')
# appended b2c23 to ('b3c7', 'mean_grad_first_100_cycles')
# appended b1c3 to ('b3c7', 'mean_grad_last_100_cycles')
# appended b2c43 to ('b3c7', 'slope_first_200_cycles')
# appended b1c4 to ('b3c7', 'slope_last_200_cycles')
# appended b2c41 to ('b3c7', 'mean_grad_first_200_cycles')
# appended b1c4 to ('b3c7', 'mean_grad_last_200_cycles')
# appended b1c11 to ('b3c7', 'slope_first_300_cycles')
# appended b1c4 to ('b3c7', 'slope_last_300_cycles')
# appended b1c18 to ('b3c7', 'mean_grad_first_300_cycles')
# appended b1c4 to ('b3c7', 'mean_grad_last_300_cycles')
# appended b1c43 to ('b3c7', 'slope_first_400_cycles')
# appended b1c4 to ('b3c7', 'slope_last_400_cycles')
# appended b1c11 to ('b3c7', 'mean_grad_first_400_cycles')
# appended b1c4 to ('b3c7', 'mean_grad_last_400_cycles')
# appended b1c36 to ('b3c7', 'slope_first_500_cycles')
# appended b1c4 to ('b3c7', 'slope_last_500_cycles')
# appended b1c15 to ('b3c7', 'mean_grad_first_500_cycles')
# appended b1c4 to ('b3c7', 'mean_grad_last_500_cycles')
# appended b1c28 to ('b3c7', 'slope_first_600_cycles')
# appended b1c4 to ('b3c7', 'slope_last_600_cycles')
# appended b1c34 to ('b3c7', 'mean_grad_first_600_cycles')
# appended b1c4 to ('b3c7', 'mean_grad_last_600_cycles')
# appended b1c24 to ('b3c7', 'slope_first_700_cycles')
# appended b1c0 to ('b3c7', 'slope_last_700_cycles')
# appended b1c29 to ('b3c7', 'mean_grad_first_700_cycles')
# appended b1c0 to ('b3c7', 'mean_grad_last_700_cycles')
# appended b1c9 to ('b3c7', 'slope_first_800_cycles')
# appended b1c0 to ('b3c7', 'slope_last_800_cycles')
# appended b1c9 to ('b3c7', 'mean_grad_first_800_cycles')
# appended b1c0 to ('b3c7', 'mean_grad_last_800_cycles')
# appended b1c0 to ('b3c7', 'slope_first_900_cycles')
# appended b1c0 to ('b3c7', 'slope_last_900_cycles')
# appended b1c5 to ('b3c7', 'mean_grad_first_900_cycles')
# appended b1c0 to ('b3c7', 'mean_grad_last_900_cycles')
# appended b1c3 to ('b3c7', 'slope_first_1000_cycles')
# appended b1c0 to ('b3c7', 'slope_last_1000_cycles')
# appended b1c3 to ('b3c7', 'mean_grad_first_1000_cycles')
# appended b1c1 to ('b3c7', 'mean_grad_last_1000_cycles')
# appended b1c27 to ('b3c8', 'total_cycles')
# appended b2c3 to ('b3c8', 'slope_first_10_cycles')
# appended b1c16 to ('b3c8', 'slope_last_10_cycles')
# appended b2c19 to ('b3c8', 'mean_grad_first_10_cycles')
# appended b2c18 to ('b3c8', 'mean_grad_last_10_cycles')
# appended b2c23 to ('b3c8', 'slope_first_50_cycles')
# appended b2c6 to ('b3c8', 'slope_last_50_cycles')
# appended b2c4 to ('b3c8', 'mean_grad_first_50_cycles')
# appended b2c6 to ('b3c8', 'mean_grad_last_50_cycles')
# appended b2c25 to ('b3c8', 'slope_first_100_cycles')
# appended b1c34 to ('b3c8', 'slope_last_100_cycles')
# appended b2c10 to ('b3c8', 'mean_grad_first_100_cycles')
# appended b1c34 to ('b3c8', 'mean_grad_last_100_cycles')
# appended b2c42 to ('b3c8', 'slope_first_200_cycles')
# appended b1c17 to ('b3c8', 'slope_last_200_cycles')
# appended b2c24 to ('b3c8', 'mean_grad_first_200_cycles')
# appended b1c26 to ('b3c8', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c8', 'slope_first_300_cycles')
# appended b1c40 to ('b3c8', 'slope_last_300_cycles')
# appended b2c33 to ('b3c8', 'mean_grad_first_300_cycles')
# appended b1c40 to ('b3c8', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c8', 'slope_first_400_cycles')
# appended b1c41 to ('b3c8', 'slope_last_400_cycles')
# appended b1c18 to ('b3c8', 'mean_grad_first_400_cycles')
# appended b1c41 to ('b3c8', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c8', 'slope_first_500_cycles')
# appended b1c24 to ('b3c8', 'slope_last_500_cycles')
# appended b1c43 to ('b3c8', 'mean_grad_first_500_cycles')
# appended b1c24 to ('b3c8', 'mean_grad_last_500_cycles')
# appended b1c33 to ('b3c8', 'slope_first_600_cycles')
# appended b1c24 to ('b3c8', 'slope_last_600_cycles')
# appended b1c30 to ('b3c8', 'mean_grad_first_600_cycles')
# appended b1c24 to ('b3c8', 'mean_grad_last_600_cycles')
# appended b1c25 to ('b3c8', 'slope_first_700_cycles')
# appended b1c15 to ('b3c8', 'slope_last_700_cycles')
# appended b1c25 to ('b3c8', 'mean_grad_first_700_cycles')
# appended b1c15 to ('b3c8', 'mean_grad_last_700_cycles')
# appended b1c27 to ('b3c8', 'slope_first_800_cycles')
# appended b1c3 to ('b3c8', 'slope_last_800_cycles')
# appended b1c25 to ('b3c8', 'mean_grad_first_800_cycles')
# appended b1c3 to ('b3c8', 'mean_grad_last_800_cycles')
# appended b1c27 to ('b3c5', 'total_cycles')
# appended b2c19 to ('b3c5', 'slope_first_10_cycles')
# appended b1c18 to ('b3c5', 'slope_last_10_cycles')
# appended b2c19 to ('b3c5', 'mean_grad_first_10_cycles')
# appended b1c18 to ('b3c5', 'mean_grad_last_10_cycles')
# appended b2c4 to ('b3c5', 'slope_first_50_cycles')
# appended b1c43 to ('b3c5', 'slope_last_50_cycles')
# appended b2c12 to ('b3c5', 'mean_grad_first_50_cycles')
# appended b1c43 to ('b3c5', 'mean_grad_last_50_cycles')
# appended b2c10 to ('b3c5', 'slope_first_100_cycles')
# appended b1c5 to ('b3c5', 'slope_last_100_cycles')
# appended b2c23 to ('b3c5', 'mean_grad_first_100_cycles')
# appended b1c5 to ('b3c5', 'mean_grad_last_100_cycles')
# appended b2c30 to ('b3c5', 'slope_first_200_cycles')
# appended b1c24 to ('b3c5', 'slope_last_200_cycles')
# appended b2c22 to ('b3c5', 'mean_grad_first_200_cycles')
# appended b1c24 to ('b3c5', 'mean_grad_last_200_cycles')
# appended b2c37 to ('b3c5', 'slope_first_300_cycles')
# appended b1c20 to ('b3c5', 'slope_last_300_cycles')
# appended b2c29 to ('b3c5', 'mean_grad_first_300_cycles')
# appended b1c20 to ('b3c5', 'mean_grad_last_300_cycles')
# appended b1c18 to ('b3c5', 'slope_first_400_cycles')
# appended b1c3 to ('b3c5', 'slope_last_400_cycles')
# appended b1c18 to ('b3c5', 'mean_grad_first_400_cycles')
# appended b1c3 to ('b3c5', 'mean_grad_last_400_cycles')
# appended b1c6 to ('b3c5', 'slope_first_500_cycles')
# appended b1c3 to ('b3c5', 'slope_last_500_cycles')
# appended b1c38 to ('b3c5', 'mean_grad_first_500_cycles')
# appended b1c3 to ('b3c5', 'mean_grad_last_500_cycles')
# appended b1c11 to ('b3c5', 'slope_first_600_cycles')
# appended b1c3 to ('b3c5', 'slope_last_600_cycles')
# appended b1c11 to ('b3c5', 'mean_grad_first_600_cycles')
# appended b1c3 to ('b3c5', 'mean_grad_last_600_cycles')
# appended b1c25 to ('b3c5', 'slope_first_700_cycles')
# appended b1c4 to ('b3c5', 'slope_last_700_cycles')
# appended b1c25 to ('b3c5', 'mean_grad_first_700_cycles')
# appended b1c4 to ('b3c5', 'mean_grad_last_700_cycles')
# appended b1c27 to ('b3c5', 'slope_first_800_cycles')
# appended b1c4 to ('b3c5', 'slope_last_800_cycles')
# appended b1c25 to ('b3c5', 'mean_grad_first_800_cycles')
# appended b1c4 to ('b3c5', 'mean_grad_last_800_cycles')
# appended b1c29 to ('b3c12', 'total_cycles')
# appended b2c19 to ('b3c12', 'slope_first_10_cycles')
# appended b1c30 to ('b3c12', 'slope_last_10_cycles')
# appended b2c19 to ('b3c12', 'mean_grad_first_10_cycles')
# appended b1c18 to ('b3c12', 'mean_grad_last_10_cycles')
# appended b2c4 to ('b3c12', 'slope_first_50_cycles')
# appended b1c37 to ('b3c12', 'slope_last_50_cycles')
# appended b2c12 to ('b3c12', 'mean_grad_first_50_cycles')
# appended b1c37 to ('b3c12', 'mean_grad_last_50_cycles')
# appended b2c11 to ('b3c12', 'slope_first_100_cycles')
# appended b2c6 to ('b3c12', 'slope_last_100_cycles')
# appended b2c10 to ('b3c12', 'mean_grad_first_100_cycles')
# appended b2c6 to ('b3c12', 'mean_grad_last_100_cycles')
# appended b2c43 to ('b3c12', 'slope_first_200_cycles')
# appended b1c17 to ('b3c12', 'slope_last_200_cycles')
# appended b2c41 to ('b3c12', 'mean_grad_first_200_cycles')
# appended b1c17 to ('b3c12', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c12', 'slope_first_300_cycles')
# appended b1c28 to ('b3c12', 'slope_last_300_cycles')
# appended b1c18 to ('b3c12', 'mean_grad_first_300_cycles')
# appended b1c28 to ('b3c12', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c12', 'slope_first_400_cycles')
# appended b1c14 to ('b3c12', 'slope_last_400_cycles')
# appended b1c11 to ('b3c12', 'mean_grad_first_400_cycles')
# appended b1c14 to ('b3c12', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c12', 'slope_first_500_cycles')
# appended b1c14 to ('b3c12', 'slope_last_500_cycles')
# appended b1c6 to ('b3c12', 'mean_grad_first_500_cycles')
# appended b1c14 to ('b3c12', 'mean_grad_last_500_cycles')
# appended b1c19 to ('b3c12', 'slope_first_600_cycles')
# appended b1c17 to ('b3c12', 'slope_last_600_cycles')
# appended b1c19 to ('b3c12', 'mean_grad_first_600_cycles')
# appended b1c17 to ('b3c12', 'mean_grad_last_600_cycles')
# appended b1c14 to ('b3c12', 'slope_first_700_cycles')
# appended b1c17 to ('b3c12', 'slope_last_700_cycles')
# appended b1c28 to ('b3c12', 'mean_grad_first_700_cycles')
# appended b1c17 to ('b3c12', 'mean_grad_last_700_cycles')
# appended b1c29 to ('b3c12', 'slope_first_800_cycles')
# appended b1c17 to ('b3c12', 'slope_last_800_cycles')
# appended b1c29 to ('b3c12', 'mean_grad_first_800_cycles')
# appended b1c17 to ('b3c12', 'mean_grad_last_800_cycles')
# appended b1c29 to ('b3c12', 'slope_first_900_cycles')
# appended b1c5 to ('b3c12', 'slope_last_900_cycles')
# appended b1c29 to ('b3c12', 'mean_grad_first_900_cycles')
# appended b1c5 to ('b3c12', 'mean_grad_last_900_cycles')
# appended b1c5 to ('b3c19', 'total_cycles')
# appended b2c19 to ('b3c19', 'slope_first_10_cycles')
# appended b1c0 to ('b3c19', 'slope_last_10_cycles')
# appended b2c19 to ('b3c19', 'mean_grad_first_10_cycles')
# appended b1c0 to ('b3c19', 'mean_grad_last_10_cycles')
# appended b2c12 to ('b3c19', 'slope_first_50_cycles')
# appended b1c41 to ('b3c19', 'slope_last_50_cycles')
# appended b2c6 to ('b3c19', 'mean_grad_first_50_cycles')
# appended b1c41 to ('b3c19', 'mean_grad_last_50_cycles')
# appended b2c23 to ('b3c19', 'slope_first_100_cycles')
# appended b1c24 to ('b3c19', 'slope_last_100_cycles')
# appended b2c23 to ('b3c19', 'mean_grad_first_100_cycles')
# appended b1c24 to ('b3c19', 'mean_grad_last_100_cycles')
# appended b2c5 to ('b3c19', 'slope_first_200_cycles')
# appended b1c20 to ('b3c19', 'slope_last_200_cycles')
# appended b2c17 to ('b3c19', 'mean_grad_first_200_cycles')
# appended b1c20 to ('b3c19', 'mean_grad_last_200_cycles')
# appended b2c29 to ('b3c19', 'slope_first_300_cycles')
# appended b1c20 to ('b3c19', 'slope_last_300_cycles')
# appended b2c29 to ('b3c19', 'mean_grad_first_300_cycles')
# ...
# appended b2c13 to ('b3c1', 'slope_first_50_cycles')
# appended b1c14 to ('b3c1', 'slope_last_50_cycles')
# appended b2c12 to ('b3c1', 'mean_grad_first_50_cycles')
# appended b1c14 to ('b3c1', 'mean_grad_last_50_cycles')
# appended b2c11 to ('b3c1', 'slope_first_100_cycles')
# appended b1c23 to ('b3c1', 'slope_last_100_cycles')
# appended b2c23 to ('b3c1', 'mean_grad_first_100_cycles')
# appended b1c11 to ('b3c1', 'mean_grad_last_100_cycles')
# appended b2c41 to ('b3c1', 'slope_first_200_cycles')
# appended b1c9 to ('b3c1', 'slope_last_200_cycles')
# appended b2c30 to ('b3c1', 'mean_grad_first_200_cycles')
# appended b1c40 to ('b3c1', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c1', 'slope_first_300_cycles')
# appended b1c18 to ('b3c1', 'slope_last_300_cycles')
# appended b2c36 to ('b3c1', 'mean_grad_first_300_cycles')
# appended b1c18 to ('b3c1', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c1', 'slope_first_400_cycles')
# appended b1c18 to ('b3c1', 'slope_last_400_cycles')
# appended b1c18 to ('b3c1', 'mean_grad_first_400_cycles')
# appended b1c18 to ('b3c1', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c1', 'slope_first_500_cycles')
# appended b1c3 to ('b3c1', 'slope_last_500_cycles')
# appended b1c37 to ('b3c1', 'mean_grad_first_500_cycles')
# appended b1c3 to ('b3c1', 'mean_grad_last_500_cycles')
# appended b1c19 to ('b3c1', 'slope_first_600_cycles')
# appended b1c3 to ('b3c1', 'slope_last_600_cycles')
# appended b1c19 to ('b3c1', 'mean_grad_first_600_cycles')
# appended b1c3 to ('b3c1', 'mean_grad_last_600_cycles')
# appended b1c29 to ('b3c1', 'slope_first_700_cycles')
# appended b1c3 to ('b3c1', 'slope_last_700_cycles')
# appended b1c14 to ('b3c1', 'mean_grad_first_700_cycles')
# appended b1c3 to ('b3c1', 'mean_grad_last_700_cycles')
# appended b1c24 to ('b3c1', 'slope_first_800_cycles')
# appended b1c3 to ('b3c1', 'slope_last_800_cycles')
# appended b1c24 to ('b3c1', 'mean_grad_first_800_cycles')
# appended b1c3 to ('b3c1', 'mean_grad_last_800_cycles')
# appended b1c41 to ('b3c1', 'slope_first_900_cycles')
# appended b1c3 to ('b3c1', 'slope_last_900_cycles')
# appended b1c23 to ('b3c1', 'mean_grad_first_900_cycles')
# appended b1c3 to ('b3c1', 'mean_grad_last_900_cycles')
# appended b1c41 to ('b3c1', 'slope_first_1000_cycles')
# appended b1c3 to ('b3c1', 'slope_last_1000_cycles')
# appended b1c23 to ('b3c1', 'mean_grad_first_1000_cycles')
# appended b1c3 to ('b3c1', 'mean_grad_last_1000_cycles')
# appended b1c19 to ('b3c21', 'total_cycles')
# appended b2c1 to ('b3c21', 'slope_first_10_cycles')
# appended b1c43 to ('b3c21', 'slope_last_10_cycles')
# appended b2c1 to ('b3c21', 'mean_grad_first_10_cycles')
# appended b1c27 to ('b3c21', 'mean_grad_last_10_cycles')
# appended b2c0 to ('b3c21', 'slope_first_50_cycles')
# appended b1c24 to ('b3c21', 'slope_last_50_cycles')
# appended b2c0 to ('b3c21', 'mean_grad_first_50_cycles')
# appended b1c24 to ('b3c21', 'mean_grad_last_50_cycles')
# appended b2c6 to ('b3c21', 'slope_first_100_cycles')
# appended b1c24 to ('b3c21', 'slope_last_100_cycles')
# appended b2c3 to ('b3c21', 'mean_grad_first_100_cycles')
# appended b1c24 to ('b3c21', 'mean_grad_last_100_cycles')
# appended b2c4 to ('b3c21', 'slope_first_200_cycles')
# appended b1c3 to ('b3c21', 'slope_last_200_cycles')
# appended b2c19 to ('b3c21', 'mean_grad_first_200_cycles')
# appended b1c3 to ('b3c21', 'mean_grad_last_200_cycles')
# appended b1c20 to ('b3c21', 'slope_first_300_cycles')
# appended b1c3 to ('b3c21', 'slope_last_300_cycles')
# appended b2c18 to ('b3c21', 'mean_grad_first_300_cycles')
# appended b1c3 to ('b3c21', 'mean_grad_last_300_cycles')
# appended b2c22 to ('b3c21', 'slope_first_400_cycles')
# appended b1c4 to ('b3c21', 'slope_last_400_cycles')
# appended b2c37 to ('b3c21', 'mean_grad_first_400_cycles')
# appended b1c4 to ('b3c21', 'mean_grad_last_400_cycles')
# appended b1c45 to ('b3c21', 'slope_first_500_cycles')
# appended b1c4 to ('b3c21', 'slope_last_500_cycles')
# appended b1c45 to ('b3c21', 'mean_grad_first_500_cycles')
# appended b1c4 to ('b3c21', 'mean_grad_last_500_cycles')
# appended b1c37 to ('b3c21', 'slope_first_600_cycles')
# appended b1c4 to ('b3c21', 'slope_last_600_cycles')
# appended b1c37 to ('b3c21', 'mean_grad_first_600_cycles')
# appended b1c4 to ('b3c21', 'mean_grad_last_600_cycles')
# appended b1c32 to ('b3c21', 'slope_first_700_cycles')
# appended b1c3 to ('b3c21', 'slope_last_700_cycles')
# appended b1c32 to ('b3c21', 'mean_grad_first_700_cycles')
# appended b1c3 to ('b3c21', 'mean_grad_last_700_cycles')
# appended b1c41 to ('b3c4', 'total_cycles')
# appended b2c19 to ('b3c4', 'slope_first_10_cycles')
# appended b1c2 to ('b3c4', 'slope_last_10_cycles')
# appended b2c19 to ('b3c4', 'mean_grad_first_10_cycles')
# appended b1c0 to ('b3c4', 'mean_grad_last_10_cycles')
# appended b2c4 to ('b3c4', 'slope_first_50_cycles')
# appended b1c41 to ('b3c4', 'slope_last_50_cycles')
# appended b2c12 to ('b3c4', 'mean_grad_first_50_cycles')
# appended b1c41 to ('b3c4', 'mean_grad_last_50_cycles')
# appended b2c10 to ('b3c4', 'slope_first_100_cycles')
# appended b1c29 to ('b3c4', 'slope_last_100_cycles')
# appended b2c23 to ('b3c4', 'mean_grad_first_100_cycles')
# appended b1c29 to ('b3c4', 'mean_grad_last_100_cycles')
# appended b2c24 to ('b3c4', 'slope_first_200_cycles')
# appended b1c41 to ('b3c4', 'slope_last_200_cycles')
# appended b2c45 to ('b3c4', 'mean_grad_first_200_cycles')
# appended b1c41 to ('b3c4', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c4', 'slope_first_300_cycles')
# appended b1c24 to ('b3c4', 'slope_last_300_cycles')
# appended b2c36 to ('b3c4', 'mean_grad_first_300_cycles')
# appended b1c24 to ('b3c4', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c4', 'slope_first_400_cycles')
# appended b1c5 to ('b3c4', 'slope_last_400_cycles')
# appended b1c18 to ('b3c4', 'mean_grad_first_400_cycles')
# appended b1c5 to ('b3c4', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c4', 'slope_first_500_cycles')
# appended b1c18 to ('b3c4', 'slope_last_500_cycles')
# appended b1c37 to ('b3c4', 'mean_grad_first_500_cycles')
# appended b1c18 to ('b3c4', 'mean_grad_last_500_cycles')
# appended b1c19 to ('b3c4', 'slope_first_600_cycles')
# appended b1c11 to ('b3c4', 'slope_last_600_cycles')
# appended b1c19 to ('b3c4', 'mean_grad_first_600_cycles')
# appended b1c11 to ('b3c4', 'mean_grad_last_600_cycles')
# appended b1c7 to ('b3c4', 'slope_first_700_cycles')
# appended b1c15 to ('b3c4', 'slope_last_700_cycles')
# appended b1c27 to ('b3c4', 'mean_grad_first_700_cycles')
# appended b1c15 to ('b3c4', 'mean_grad_last_700_cycles')
# appended b1c40 to ('b3c4', 'slope_first_800_cycles')
# appended b1c5 to ('b3c4', 'slope_last_800_cycles')
# appended b1c40 to ('b3c4', 'mean_grad_first_800_cycles')
# appended b1c5 to ('b3c4', 'mean_grad_last_800_cycles')
# appended b1c24 to ('b3c4', 'slope_first_900_cycles')
# appended b1c5 to ('b3c4', 'slope_last_900_cycles')
# appended b1c24 to ('b3c4', 'mean_grad_first_900_cycles')
# appended b1c5 to ('b3c4', 'mean_grad_last_900_cycles')
# appended b1c24 to ('b3c4', 'slope_first_1000_cycles')
# appended b1c3 to ('b3c4', 'slope_last_1000_cycles')
# appended b1c24 to ('b3c4', 'mean_grad_first_1000_cycles')
# appended b1c3 to ('b3c4', 'mean_grad_last_1000_cycles')
# appended b1c17 to ('b3c29', 'total_cycles')
# appended b2c3 to ('b3c29', 'slope_first_10_cycles')
# appended b1c15 to ('b3c29', 'slope_last_10_cycles')
# appended b2c19 to ('b3c29', 'mean_grad_first_10_cycles')
# appended b1c23 to ('b3c29', 'mean_grad_last_10_cycles')
# appended b2c23 to ('b3c29', 'slope_first_50_cycles')
# appended b1c31 to ('b3c29', 'slope_last_50_cycles')
# appended b2c23 to ('b3c29', 'mean_grad_first_50_cycles')
# appended b1c44 to ('b3c29', 'mean_grad_last_50_cycles')
# appended b2c21 to ('b3c29', 'slope_first_100_cycles')
# appended b1c42 to ('b3c29', 'slope_last_100_cycles')
# appended b2c25 to ('b3c29', 'mean_grad_first_100_cycles')
# appended b1c26 to ('b3c29', 'mean_grad_last_100_cycles')
# appended b2c42 to ('b3c29', 'slope_first_200_cycles')
# appended b1c18 to ('b3c29', 'slope_last_200_cycles')
# appended b2c24 to ('b3c29', 'mean_grad_first_200_cycles')
# appended b1c18 to ('b3c29', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c29', 'slope_first_300_cycles')
# appended b1c5 to ('b3c29', 'slope_last_300_cycles')
# appended b2c34 to ('b3c29', 'mean_grad_first_300_cycles')
# appended b1c5 to ('b3c29', 'mean_grad_last_300_cycles')
# appended b1c18 to ('b3c29', 'slope_first_400_cycles')
# appended b1c24 to ('b3c29', 'slope_last_400_cycles')
# appended b1c18 to ('b3c29', 'mean_grad_first_400_cycles')
# appended b1c24 to ('b3c29', 'mean_grad_last_400_cycles')
# appended b1c6 to ('b3c29', 'slope_first_500_cycles')
# appended b1c24 to ('b3c29', 'slope_last_500_cycles')
# appended b1c38 to ('b3c29', 'mean_grad_first_500_cycles')
# appended b1c24 to ('b3c29', 'mean_grad_last_500_cycles')
# appended b1c11 to ('b3c29', 'slope_first_600_cycles')
# appended b1c24 to ('b3c29', 'slope_last_600_cycles')
# appended b1c11 to ('b3c29', 'mean_grad_first_600_cycles')
# appended b1c24 to ('b3c29', 'mean_grad_last_600_cycles')
# appended b1c25 to ('b3c29', 'slope_first_700_cycles')
# appended b1c24 to ('b3c29', 'slope_last_700_cycles')
# appended b1c25 to ('b3c29', 'mean_grad_first_700_cycles')
# appended b1c24 to ('b3c29', 'mean_grad_last_700_cycles')
# appended b1c27 to ('b3c29', 'slope_first_800_cycles')
# appended b1c5 to ('b3c29', 'slope_last_800_cycles')
# appended b1c25 to ('b3c29', 'mean_grad_first_800_cycles')
# appended b1c5 to ('b3c29', 'mean_grad_last_800_cycles')
# appended b1c3 to ('b3c33', 'total_cycles')
# appended b2c19 to ('b3c33', 'slope_first_10_cycles')
# appended b1c41 to ('b3c33', 'slope_last_10_cycles')
# appended b2c19 to ('b3c33', 'mean_grad_first_10_cycles')
# appended b1c41 to ('b3c33', 'mean_grad_last_10_cycles')
# appended b2c12 to ('b3c33', 'slope_first_50_cycles')
# appended b1c41 to ('b3c33', 'slope_last_50_cycles')
# appended b2c6 to ('b3c33', 'mean_grad_first_50_cycles')
# appended b1c41 to ('b3c33', 'mean_grad_last_50_cycles')
# appended b2c10 to ('b3c33', 'slope_first_100_cycles')
# appended b1c41 to ('b3c33', 'slope_last_100_cycles')
# appended b2c23 to ('b3c33', 'mean_grad_first_100_cycles')
# appended b1c41 to ('b3c33', 'mean_grad_last_100_cycles')
# appended b2c24 to ('b3c33', 'slope_first_200_cycles')
# appended b1c20 to ('b3c33', 'slope_last_200_cycles')
# appended b2c14 to ('b3c33', 'mean_grad_first_200_cycles')
# appended b1c20 to ('b3c33', 'mean_grad_last_200_cycles')
# appended b2c33 to ('b3c33', 'slope_first_300_cycles')
# appended b1c3 to ('b3c33', 'slope_last_300_cycles')
# appended b2c36 to ('b3c33', 'mean_grad_first_300_cycles')
# appended b1c3 to ('b3c33', 'mean_grad_last_300_cycles')
# appended b1c11 to ('b3c33', 'slope_first_400_cycles')
# appended b1c3 to ('b3c33', 'slope_last_400_cycles')
# appended b1c18 to ('b3c33', 'mean_grad_first_400_cycles')
# appended b1c3 to ('b3c33', 'mean_grad_last_400_cycles')
# appended b1c11 to ('b3c33', 'slope_first_500_cycles')
# appended b1c4 to ('b3c33', 'slope_last_500_cycles')
# appended b1c37 to ('b3c33', 'mean_grad_first_500_cycles')
# appended b1c4 to ('b3c33', 'mean_grad_last_500_cycles')
# appended b1c19 to ('b3c33', 'slope_first_600_cycles')
# appended b1c4 to ('b3c33', 'slope_last_600_cycles')
# appended b1c34 to ('b3c33', 'mean_grad_first_600_cycles')
# appended b1c4 to ('b3c33', 'mean_grad_last_600_cycles')
# appended b1c16 to ('b3c33', 'slope_first_700_cycles')
# appended b1c4 to ('b3c33', 'slope_last_700_cycles')
# appended b1c16 to ('b3c33', 'mean_grad_first_700_cycles')
# appended b1c4 to ('b3c33', 'mean_grad_last_700_cycles')
# appended b1c23 to ('b3c33', 'slope_first_800_cycles')
# appended b1c4 to ('b3c33', 'slope_last_800_cycles')
# appended b1c24 to ('b3c33', 'mean_grad_first_800_cycles')
# appended b1c4 to ('b3c33', 'mean_grad_last_800_cycles')
# appended b1c5 to ('b3c33', 'slope_first_900_cycles')
# appended b1c4 to ('b3c33', 'slope_last_900_cycles')
# appended b1c5 to ('b3c33', 'mean_grad_first_900_cycles')
# appended b1c4 to ('b3c33', 'mean_grad_last_900_cycles')
# appended b1c3 to ('b3c33', 'slope_first_1000_cycles')
# appended b1c4 to ('b3c33', 'slope_last_1000_cycles')
# appended b1c5 to ('b3c33', 'mean_grad_first_1000_cycles')
# appended b1c4 to ('b3c33', 'mean_grad_last_1000_cycles')
# {('b3c18', 'total_cycles'): ['b1c5'], ('b3c18', 'slope_first_10_cycles'): ['b2c19'], ('b3c18', 'slope_last_10_cycles'): ['b1c0'], ('b3c18', 'mean_grad_first_10_cycles'): ['b2c1'], ('b3c18', 'mean_grad_last_10_cycles'): ['b1c0'], ('b3c18', 'slope_first_50_cycles'): ['b2c6'], ('b3c18', 'slope_last_50_cycles'): ['b1c2'], ('b3c18', 'mean_grad_first_50_cycles'): ['b2c6'], ('b3c18', 'mean_grad_last_50_cycles'): ['b1c2'], ('b3c18', 'slope_first_100_cycles'): ['b2c23'], ('b3c18', 'slope_last_100_cycles'): ['b1c24'], ('b3c18', 'mean_grad_first_100_cycles'): ['b2c18'], ('b3c18', 'mean_grad_last_100_cycles'): ['b1c24'], ('b3c18', 'slope_first_200_cycles'): ['b2c22'], ('b3c18', 'slope_last_200_cycles'): ['b1c20'], ('b3c18', 'mean_grad_first_200_cycles'): ['b2c35'], ('b3c18', 'mean_grad_last_200_cycles'): ['b1c20'], ('b3c18', 'slope_first_300_cycles'): ['b2c37'], ('b3c18', 'slope_last_300_cycles'): ['b1c20'], ('b3c18', 'mean_grad_first_300_cycles'): ['b2c39'], ('b3c18', 'mean_grad_last_300_cycles'): ['b1c20'], ('b3c18', 'slope_first_400_cycles'): ['b1c18'], ('b3c18', 'slope_last_400_cycles'): ['b1c3'], ('b3c18', 'mean_grad_first_400_cycles'): ['b1c18'], ('b3c18', 'mean_grad_last_400_cycles'): ['b1c3'], ('b3c18', 'slope_first_500_cycles'): ['b1c11'], ('b3c18', 'slope_last_500_cycles'): ['b1c3'], ('b3c18', 'mean_grad_first_500_cycles'): ['b1c43'], ('b3c18', 'mean_grad_last_500_cycles'): ['b1c3'], ('b3c18', 'slope_first_600_cycles'): ['b1c19'], ('b3c18', 'slope_last_600_cycles'): ['b1c3'], ('b3c18', 'mean_grad_first_600_cycles'): ['b1c19'], ('b3c18', 'mean_grad_last_600_cycles'): ['b1c3'], ('b3c18', 'slope_first_700_cycles'): ['b1c7'], ('b3c18', 'slope_last_700_cycles'): ['b1c3'], ('b3c18', 'mean_grad_first_700_cycles'): ['b1c27'], ('b3c18', 'mean_grad_last_700_cycles'): ['b1c3'], ('b3c18', 'slope_first_800_cycles'): ['b1c24'], ('b3c18', 'slope_last_800_cycles'): ['b1c4'], ('b3c18', 'mean_grad_first_800_cycles'): ['b1c40'], ('b3c18', 'mean_grad_last_800_cycles'): ['b1c4'], ('b3c18', 'slope_first_900_cycles'): ['b1c9'], ('b3c18', 'slope_last_900_cycles'): ['b1c3'], ('b3c18', 'mean_grad_first_900_cycles'): ['b1c9'], ('b3c18', 'mean_grad_last_900_cycles'): ['b1c3'], ('b3c18', 'slope_first_1000_cycles'): ['b1c5'], ('b3c18', 'slope_last_1000_cycles'): ['b1c4'], ('b3c18', 'mean_grad_first_1000_cycles'): ['b1c5'], ('b3c18', 'mean_grad_last_1000_cycles'): ['b1c4'], ('b3c24', 'total_cycles'): ['b1c27'], ('b3c24', 'slope_first_10_cycles'): ['b2c3'], ('b3c24', 'slope_last_10_cycles'): ['b1c33'], ('b3c24', 'mean_grad_first_10_cycles'): ['b2c19'], ('b3c24', 'mean_grad_last_10_cycles'): ['b1c7'], ('b3c24', 'slope_first_50_cycles'): ['b2c23'], ('b3c24', 'slope_last_50_cycles'): ['b1c39'], ('b3c24', 'mean_grad_first_50_cycles'): ['b2c23'], ('b3c24', 'mean_grad_last_50_cycles'): ['b1c39'], ('b3c24', 'slope_first_100_cycles'): ['b2c21'], ('b3c24', 'slope_last_100_cycles'): ['b1c36'], ('b3c24', 'mean_grad_first_100_cycles'): ['b2c26'], ('b3c24', 'mean_grad_last_100_cycles'): ['b1c36'], ('b3c24', 'slope_first_200_cycles'): ['b2c38'], ('b3c24', 'slope_last_200_cycles'): ['b1c40'], ('b3c24', 'mean_grad_first_200_cycles'): ['b2c42'], ('b3c24', 'mean_grad_last_200_cycles'): ['b1c41'], ('b3c24', 'slope_first_300_cycles'): ['b2c33'], ('b3c24', 'slope_last_300_cycles'): ['b1c20'], ('b3c24', 'mean_grad_first_300_cycles'): ['b2c36'], ('b3c24', 'mean_grad_last_300_cycles'): ['b1c20'], ('b3c24', 'slope_first_400_cycles'): ['b1c11'], ('b3c24', 'slope_last_400_cycles'): ['b1c3'], ('b3c24', 'mean_grad_first_400_cycles'): ['b1c18'], ('b3c24', 'mean_grad_last_400_cycles'): ['b1c3'], ('b3c24', 'slope_first_500_cycles'): ['b1c11'], ('b3c24', 'slope_last_500_cycles'): ['b1c3'], ('b3c24', 'mean_grad_first_500_cycles'): ['b1c43'], ('b3c24', 'mean_grad_last_500_cycles'): ['b1c3'], ('b3c24', 'slope_first_600_cycles'): ['b1c33'], ('b3c24', 'slope_last_600_cycles'): ['b1c3'], ('b3c24', 'mean_grad_first_600_cycles'): ['b1c30'], ('b3c24', 'mean_grad_last_600_cycles'): ['b1c3'], ('b3c24',  ...

# %%
def map_feature_to_ground_truth_key(full_feature_name): return full_feature_name  # fallback


# ─── Feature Extraction ──────────────────────────────────────────
def extract_features_from_sample_battery_from_text(file_text: str):
    q_d_n_values = [float(line.strip().rstrip(',')) for line in file_text.splitlines() if line.strip()]
    q_d_n_array = np.array(q_d_n_values)
    trimmed_q_d_n = np.trim_zeros(q_d_n_array, 'b')
    total_cycles = len(trimmed_q_d_n)
    features = {}

    for k in K_VALUES:
        if total_cycles > k:
            slope_last = (trimmed_q_d_n[-1] - trimmed_q_d_n[-k]) / k
            grad_last = np.gradient(trimmed_q_d_n[-k:], 1)
            mean_grad_last = float(np.mean(grad_last))
        else:
            slope_last = np.nan
            mean_grad_last = np.nan

        features[f'slope_last_{k}_cycles'] = slope_last
        features[f'mean_grad_last_{k}_cycles'] = mean_grad_last

        if total_cycles > k:
            slope_first = (trimmed_q_d_n[k-1] - trimmed_q_d_n[0]) / k
            grad_first = np.gradient(trimmed_q_d_n[:k], 1)
            mean_grad_first = float(np.mean(grad_first))
        else:
            slope_first = np.nan
            mean_grad_first = np.nan

        features[f'slope_first_{k}_cycles'] = slope_first
        features[f'mean_grad_first_{k}_cycles'] = mean_grad_first

    features['total_cycles'] = total_cycles
    return features

# ─── Neo4j Query ────────────────────────────────────────────────
def query_top_n(feature, value, N):
    query = f"""
    MATCH (b:Battery)
    WHERE b.{feature} IS NOT NULL
    RETURN b.battery_id AS battery_id, abs(b.{feature} - $val) AS diff
    ORDER BY diff ASC
    LIMIT $N
    """
    with driver.session() as session:
        result = session.run(query, val=value, N=N)
        return [record['battery_id'] for record in result]
# ─── Main Loop ───────────────────────────────────────────────────
results = []

for path in tqdm(battery_paths, desc="🔋 Processing batteries"):
    battery_id = os.path.basename(path).replace(".txt", "")
    with open(path, 'r') as f:
        file_text = f.read()
    features = extract_features_from_sample_battery_from_text(file_text)

    feature_items = [
        (k, v) for k, v in features.items()
        if "total_cycles" not in k and not pd.isna(v)
    ]

    for full_feature_name, value in tqdm(feature_items, leave=False, desc=f"📐 {battery_id} features"):
        parts = full_feature_name.split("_")
        if parts[0] == "slope":
            feature_type = "slope_" + parts[1]
        elif parts[0] == "mean":
            feature_type = "mean_grad_" + parts[2]
        k = int(parts[-2])

        if features["total_cycles"] <= k:
            continue
        
        gt_key = (battery_id, full_feature_name)
        gt_ids = ground_truth[gt_key]

        max_N = max(TOP_N)
        top_ids_full = query_top_n(full_feature_name, value, max_N)
        
        for N in TOP_N:
            top_n_ids = top_ids_full[:N]
            matched_ranks = [top_n_ids.index(gt_id) + 1 for gt_id in gt_ids if gt_id in top_n_ids]
            hit = int(any(gt_id in top_n_ids for gt_id in gt_ids))
            if matched_ranks:
                best_rank = min(matched_ranks)
                rr = 1 / best_rank
            else:
                best_rank = 0
                rr = 0
        
            results.append({
                "battery_id": battery_id,
                "feature_type": feature_type,
                "k": k,
                "N": N,
                "hit": hit,
                "reciprocal_rank": rr
            })



# ─── Save CSV ────────────────────────────────────────────────────
df = pd.DataFrame(results)
df.to_csv("ranking_results_typeB.csv", index=False)
print("✅ Saved to ranking_results_typeB.csv")
# Out:
# 🔋 Processing batteries: 100%|██████████| 40/40 [01:57<00:00,  2.94s/it]
# ✅ Saved to ranking_results_typeB.csv

# %%
# ─── Plot Heatmaps ───────────────────────────────────────────────
for ft in df["feature_type"].unique():
    subset = df[df["feature_type"] == ft]

    # # Plot Mean Rank
    rank_data = subset.groupby(["k", "N"])["hit"].mean().unstack()
    plt.figure(figsize=(10, 6))
    sns.heatmap(rank_data, annot=True, fmt=".2f", cmap="Reds", cbar_kws={"label": "Avg Rank"})
    plt.title(f"Accuracy — {ft}")
    plt.xlabel("Top-N")
    plt.ylabel("k cycles")
    plt.tight_layout()
    plt.savefig(f"heatmap_rank_{ft}.png")
    plt.show()

# %%
# ─── Plot Heatmaps ───────────────────────────────────────────────
for ft in df["feature_type"].unique():
    subset = df[df["feature_type"] == ft]

    # Plot MRR
    mrr_data = subset.groupby(["k", "N"])["reciprocal_rank"].mean().unstack()
    plt.figure(figsize=(10, 6))
    sns.heatmap(mrr_data, annot=True, fmt=".2f", cmap="YlGnBu", cbar_kws={"label": "MRR"})
    plt.title(f"Mean Reciprocal Rank (MRR) — {ft}")
    plt.xlabel("Top-N")
    plt.ylabel("k cycles")
    plt.tight_layout()
    plt.savefig(f"heatmap_mrr_{ft}.png")
    plt.show()
